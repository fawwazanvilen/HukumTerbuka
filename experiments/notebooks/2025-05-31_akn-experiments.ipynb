# %%
# Basic imports
import json
import os
from datetime import datetime, timezone
import uuid
from typing import List, Dict, Any, Optional

# OpenAI client (or your preferred LLM client)
from openai import AsyncOpenAI

# Weave for tracing (optional, if you're using it)
import weave

# MongoDB
import motor
from motor.motor_asyncio import AsyncIOMotorClient
import motor.motor_asyncio # Make sure this import is at the top of your file
import pymongo # For ObjectId, and some potential sync operations or type hints

# XML Processing
from lxml import etree # Preferred for robust XML/XPath/Namespace handling

# Pydantic for structuring tool inputs and some internal models
from pydantic import BaseModel, Field

print("Imports successful.")
# Out:
# Imports successful.

# %%
# Initialize Weave Tracing
weave.init('HukumTerbuka')

# %%
# Akoma Ntoso v3.0 Namespace
AKN_NAMESPACE = "http://docs.oasis-open.org/legaldocml/ns/akn/3.0"
NSMAP = {None: AKN_NAMESPACE} # Default namespace for lxml

# --- Indonesian Legal Structure to AKN Mapping (Revised and Opinionated v2) ---
AKN_STRUCTURE_MAPPING_INFO = """
Akoma Ntoso (AKN) v3.0 Mapping for Indonesian Legal Documents:

**A. General Principles**:
1.  **Document Root**: For Undang-Undang (UU), use `<akomaNtoso><act name="indonesianAct" eId="act" ...>`. The `eId="act"` for the root act element is a mandatory convention.
2.  **`eId` (Element ID) Strategy**:
    * Crucial for all addressable structural elements.
    * Hierarchical and predictable: `parentElementeId__elementTypePrefix_sequentialNumber` (e.g., `act__body__art_1`).
    * Use `act` as the top-level parent `eId`.
    * Common prefixes:
        * `meta`, `identification`, `publication`
        * `preamble`, `doctitle` (for titles in preamble), `rec` (recital), `cit` (citation), `formula`
        * `body`
        * `ch` (chapter), `sec` (section - for Bagian), `subsec` (subsection - for Paragraf structure if it has a heading/number)
        * `art` (article - for Pasal), `para` (paragraph - for Ayat)
        * `list` (for a list within an Ayat/paragraph), `point` (for an item 'a.', 'b.' in a list)
        * `conclusions`, `signatureBlock`, `signature`
        * `attachments`, `elucidation` (for the attachment itself), `elucGeneral` (general elucidation), `elucArt` (article-specific elucidation clause)
    * Example: `act__body__art_1` (Pasal 1), `act__body__art_1__para_1` (Ayat 1 of Pasal 1), `act__body__art_1__para_1__list_1__point_a` (Point 'a' in Ayat 1 of Pasal 1).
    * Generate `eId`s sequentially within their parent: `art_1`, `art_2`; `para_1`, `para_2`.
    * Avoid adding `eId`s to basic `<p>` tags unless they represent a distinct, addressable block or are directly referenced by other parts of the document. Numbered/lettered points in a list MUST have `eId`s.

**B. Document Structure Mapping**:

1.  **Metadata (`<meta eId="act__meta">`)**:
    * `identification source="#sourceSystem" eId="act__meta__identification"`: Contains FRBR elements.
        * `FRBRWork eId="act__meta__identification__work"`:
            * `FRBRthis value="/akn/id/undang-undang/YYYY/NN/main"` (Use 'undang-undang' for UU type)
            * `FRBRuri value="/akn/id/undang-undang/YYYY/NN"`
            * `FRBRdate date="YYYY-MM-DD" name="creation"` (Use 'creation' for the conceptual work date. If only the year is known, use YYYY-01-01. If year and month are known, use YYYY-MM-01.)
            * `FRBRauthor href="#sistem" as="#author"` (Use `#sistem` as the default author reference)
            * `FRBRcountry value="id"`
            * `FRBRname value="[JUDUL LENGKAP UNDANG-UNDANG]"`
            * `FRBRnumber value="[NOMOR UU]"`
        * `FRBRManifestation eId="act__meta__identification__manifestation"`:
            * `FRBRthis value="/akn/id/undang-undang/YYYY/NN/id@YYYY-MM-DD_publication/main.xml"` (Manifestation `FRBRthis/@value` MUST include the manifestation's publication date for versioning clarity.)
            * `FRBRuri value="/akn/id/undang-undang/YYYY/NN/id@YYYY-MM-DD_publication.xml"` (Manifestation `FRBRuri/@value` MUST also reflect this publication date.)
            * `FRBRdate date="YYYY-MM-DD" name="publication"` (Actual publication date of *this XML version*)
            * `FRBRformat value="application/akn+xml"`
    * `publication` elements:
        * For Lembaran Negara (LN): `publication eId="act__meta__publication_ln_[YYYY]_[LN_NUMBER]" name="LembaranNegara" showAs="Lembaran Negara Republik Indonesia Nomor [LN_NUMBER] Tahun [YYYY]" date="[YYYY-MM-DD_LN_Date]" number="[LN_NUMBER]" TLA="LNRI"`.
        * For Tambahan Lembaran Negara (TLN): `publication eId="act__meta__publication_tln_[YYYY]_[TLN_NUMBER]" name="TambahanLembaranNegara" showAs="Tambahan Lembaran Negara Republik Indonesia Nomor [TLN_NUMBER] Tahun [YYYY]" date="[YYYY-MM-DD_TLN_Date]" number="[TLN_NUMBER]" TLA="TLNRI"`.
        * **Date Normalization for `publication@date`**: If a source date for LN/TLN has an unknown month or day (e.g., '1961-00-00' or just '1961'), it MUST be normalized to a valid `xs:date`. Use '01' for the unknown day and/or '01' for the unknown month. For example, '1961-00-00' becomes '1961-01-01'. If only the year is known, it becomes 'YYYY-01-01'.
        * **Multiple LN/TLN Entries**: If multiple Lembaran Negara (or Tambahan Lembaran Negara) entries are associated with the law, generate a separate `<publication>` element for each. The `eId` MUST be unique, typically by using the specific LN/TLN number within the `eId` (e.g., `act__meta__publication_ln_1961_41`, `act__meta__publication_ln_1961_207`). The `showAs`, `date`, and `number` attributes must reflect the specific entry.
    * `lifecycle source="#sourceSystem" eId="act__meta__lifecycle"`:
        * This element MUST be present.
        * It MUST include at least `<eventRef date="[YYYY-MM-DD_enactment]" source="#sourceSystem" eId="act__meta__lifecycle__enactment_1" type="enactment"/>` (Normalize enactment date similar to publication dates if components are unknown).
    * `references source="#sourceSystem" eId="act__meta__references"`:
        * This element MUST be present.
        * It MUST define standard authorities like `#presidenRI`, `#dprRI`, `#sekretarisNegara`, `#menteriHukumDanHamRI`, etc., using `<TLCPerson>`, `<TLCOrganization>`, or `<TLCRole>` as appropriate. Example: `<TLCRole eId="presidenRI" href="/ontology/role/id/presidenRI" showAs="Presiden Republik Indonesia"/>`. These definitions are for use in `refersTo` attributes in the document.

2.  **Preamble (`<preamble eId="act__preamble">`)**:
    * Document Title components (e.g., "UNDANG-UNDANG REPUBLIK INDONESIA", "NOMOR 8 TAHUN 1961", "TENTANG", "WAJIB KERJA SARJANA"): Each MUST be in a separate `<docTitle>` element.
    * Presidential line: `<docTitle eId="act__preamble__doctitle_[N]">PRESIDEN REPUBLIK INDONESIA,</docTitle>`
    * **`eId` for preamble `<docTitle>`s**: All `<docTitle>` elements within the `<preamble>` MUST be assigned `eId`s sequentially starting from `_1` within the preamble scope (e.g., `act__preamble__doctitle_1`, `act__preamble__doctitle_2`, and so on, in document order).
    * `Menimbang:`: `<recitals eId="act__preamble__recitals_1" name="considerations">`. Each point `a. ...;` becomes `<recital eId="act__preamble__recitals_1__rec_a"><num>a.</num><p>[Full text of recital point, without the 'a.']</p></recital>`.
    * `Mengingat:`: `<citations eId="act__preamble__citations_1" name="references">`. Each point `a. ...;` becomes `<citation eId="act__preamble__citations_1__cit_a"><num>a.</num><p>[Full text of citation point, without the 'a.']</p></citation>`.
    * `Dengan persetujuan...;`: MUST use `<container name="approvalStatement" eId="act__preamble__approval_1"><p>Dengan persetujuan Dewan Perwakilan Rakyat Gotong Royong;</p></container>` (or similar text, ensure it's wrapped in `<p>`).
    * `MEMUTUSKAN :`: MUST use `<formula name="decision" eId="act__preamble__formula_decision"><p>MEMUTUSKAN :</p></formula>`
    * `I. Mencabut...;`: `<container name="revocation" eId="act__preamble__revocation_1"><num>I.</num><content><p>Mencabut: Undang-Undang Nomor X tahun YYYY (...);</p></content></container>` (Ensure content is wrapped appropriately, usually `<p>`).
    * `II. Menetapkan: ...`: `<enactingFormula eId="act__preamble__enactingFormula_1" name="enactingFormula"><num>II.</num><p>Menetapkan: <docType refersTo="#act">UNDANG-UNDANG</docType> TENTANG <docTitle refersTo="#mainTitle">[JUDUL PENDEK UNDANG-UNDANG]</docTitle>.</p></enactingFormula>`

3.  **Body (`<body eId="act__body">`)**:
    * `BAB X JUDUL BAB`: `<chapter eId="act__body__ch_X" num="X"><num>BAB X</num><heading>JUDUL BAB</heading> ... </chapter>`. The `num` attribute MUST NOT contain a trailing dot. The text in `<num>` MUST NOT have a trailing dot. The text in `<heading>` MUST NOT have a trailing dot unless grammatically part of the title itself.
    * `Pasal N`: `<article eId="act__body__art_N" num="N"><num>Pasal N</num><content> ... </content></article>`. The `num` attribute MUST NOT contain a trailing dot. The text in `<num>` MUST NOT have a trailing dot. If Pasal has a title: `<heading>Judul Pasal</heading>` after `<num>`. The text in `<heading>` MUST NOT have a trailing dot unless grammatically part of the title.
    * `Ayat (M)`: Within `<article><content>`, use `<paragraph eId="act__body__art_N__para_M" num="(M)"><num>(M)</num><content><p>[Full text of Ayat, corrected for OCR errors and normalized]</p></content></paragraph>`. The `num` attribute for `paragraph` represents the number as string, e.g., "(M)". The text within `<num>` should match this.
    * Lists within Ayat: `<list eId="act__body__art_N__para_M__list_1" type="alpha|decimal|roman|etc."><point eId="act__body__art_N__para_M__list_1__point_a"><num>a.</num><content><p>[Text of point a]</p></content></point> ... </list>`. The text in `<num>` for a point MUST NOT have a trailing dot if the source uses one purely for list formatting (e.g., "a." becomes "a").
    * Concluding sentences of an Ayat after a list: MUST be a new `<p>` within the Ayat's main `<content>` tag, after the `<list>` tag. If it directly concludes the very last point and is semantically part of it, it can be part of that point's final `<p>`; however, for general conclusions to the Ayat, a separate `<p>` after the `<list>` is strongly preferred for clarity.

4.  **Concluding Provisions (Usually last Articles in `<body>`)**:
    * Example: Transitional provisions, closing articles.
    * Promulgation command: `<container name="promulgationCommand" eId="act__body__promulgationCommand_1"><p>Agar setiap orang mengetahuinya, memerintahkan pengundangan Undang-Undang ini dengan penempatannya dalam Lembaran Negara Republik Indonesia.</p></container>`. (Standardized text and eId).

5.  **Signatures & Dates (`<conclusions eId="act__conclusions">`)**: (This specific clean structure MUST be enforced to avoid redundancy)
    * **Block for "Disahkan di..." (President/Enacting Authority):**
        * `<container name="signatureBlock" eId="act__conclusions__signatureBlock_1">`
            * `<container name="placeDateOfSignature" eId="act__conclusions__signatureBlock_1__placeDate"><p>Disahkan di [Tempat]</p><p>pada tanggal [DD MMMM YYYY]</p></container>` (Date format here is textual month).
            * `<signature eId="act__conclusions__signatureBlock_1__signature_1"><role refersTo="#[roleRef_enacting]">[Jabatan Penandatangan]</role><person refersTo="#[personRef_enacting]">[Nama Penandatangan]</person></signature>`
        * `</container>`
    * **Block for "Diundangkan di..." (Minister/Promulgating Authority):**
        * `<container name="promulgationBlock" eId="act__conclusions__promulgationBlock_1">`
            * `<container name="placeDateOfPromulgation" eId="act__conclusions__promulgationBlock_1__placeDate"><p>Diundangkan di [Tempat]</p><p>pada tanggal [DD MMMM YYYY]</p></container>` (Date format here is textual month).
            * `<signature eId="act__conclusions__promulgationBlock_1__signature_1"><role refersTo="#[roleRef_promulgating]">[Jabatan Sekretaris Negara/Menteri terkait]</role><person refersTo="#[personRef_promulgating]">[Nama Sekretaris Negara/Menteri terkait]</person></signature>`
        * `</container>`

6.  **`PENJELASAN` (Elucidation)**:
    * Main wrapper: `<attachments eId="act__attachments">`
    * Elucidation document: `<attachment eId="act__elucidation_1" type="elucidation">` (Use `_1` in case of multiple elucidations, though rare for UU).
        * Elucidation metadata: `<meta eId="act__elucidation_1__meta"> ... </meta>` (This SHOULD be included, minimally with its own FRBR Work/Expression for the elucidation itself if treated as a separate document conceptually).
        * Elucidation preface: `<preface eId="act__elucidation_1__preface"><docTitle eId="act__elucidation_1__preface__title_1">[JUDUL LENGKAP PENJELASAN, without trailing dot]</docTitle></preface>` (Single `docTitle` for full elucidation title. Text MUST NOT have a trailing dot unless part of the actual title).
        * Elucidation body: `<body eId="act__elucidation_1__body">`
            * `PENJELASAN UMUM.`: `<container name="generalExplanation" eId="act__elucidation_1__body__elucGeneral_1"><heading>PENJELASAN UMUM</heading><p>[Text paragraph 1]</p><p>[Text paragraph 2]</p>... </container>` (Heading text `PENJELASAN UMUM` MUST NOT have a trailing dot).
            * `PENJELASAN PASAL DEMI PASAL.`: `<container name="articleByArticleExplanation" eId="act__elucidation_1__body__elucArtByArt_1"><heading>PASAL DEMI PASAL</heading> ... </container>` (Heading text `PASAL DEMI PASAL` MUST NOT have a trailing dot).
                * `Pasal 1.`: `<clause eId="act__elucidation_1__body__elucArtByArt_1__art_1" refersTo="#act__body__art_1"><heading>Pasal 1</heading><p>[Text of elucidation for Pasal 1]</p></clause>` (Heading text `Pasal N` MUST NOT have a trailing dot. `refersTo` must be specific and start with `#act__...`).
                * `Pasal 2 dan 3.`: `<clause eId="act__elucidation_1__body__elucArtByArt_1__art_2-3" refersTo="#act__body__art_2 #act__body__art_3"><heading>Pasal 2 dan Pasal 3</heading><p>[Text of elucidation]</p></clause>` (Heading text MUST explicitly list each article number like `Pasal X dan Pasal Y`. `refersTo` lists all referenced article eIds).

**C. Agent Instructions Reminder (Not part of mapping, but for the agent's system prompt)**:
* You MUST generate valid XML adhering to these specific mappings and conventions. Any "Opinion:" or "MUST" statement in the mapping above is a strict requirement.
* All `eId`s MUST be unique and follow the hierarchical pattern starting from `act`.
* `num` attributes for Articles, Chapters, Paragraphs (Ayat), list points, etc., MUST NOT contain trailing dots (e.g., `num="1"`, not `num="1."`). The text content of corresponding `<num>` elements should also be cleaned of purely formatting dots.
* Pay extremely close attention to text correction, whitespace normalization (trim leading/trailing spaces, normalize internal spaces), and avoiding duplication from source OCR errors. If the source text contains apparent OCR errors or formatting inconsistencies (e.g., 'Pasal. 1' vs 'Pasal 1', inconsistent list numbering styles), these MUST be normalized according to the rules and intended semantic structure outlined in this prompt.
* When referring to elements (e.g., in `refersTo`), use the full `eId` (e.g., `#act__body__art_1`).
* Concluding sentences after lists in Ayats MUST be handled as specified (prefer separate `<p>`).
* The `<conclusions>` section MUST follow the precise structure given to avoid redundancy.
* Titles/Headings in the main document and in Elucidation MUST NOT have trailing dots in their text content, unless the dot is grammatically part of the official title itself.
"""

print("Revised Akoma Ntoso configuration loaded.")
# For debugging or inspection:
# print(AKN_STRUCTURE_MAPPING_INFO)
# Out:
# Revised Akoma Ntoso configuration loaded.

# %%
# Ensure your API key is set as an environment variable
# OPENROUTER_API_KEY or OPENAI_API_KEY
# For OpenRouter:
client = AsyncOpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTER_API_KEY"),
)
# Or for OpenAI:
# client = AsyncOpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# Select your preferred model
# LLM_MODEL = "openai/gpt-4o"
# LLM_MODEL = "openai/gpt-4-turbo"
LLM_MODEL = "google/gemini-2.5-flash-preview-05-20" # Example
# LLM_MODEL = "anthropic/claude-3.5-sonnet"

print(f"Using LLM Model: {LLM_MODEL}")
# Out:
# Using LLM Model: google/gemini-2.5-flash-preview-05-20

# %%
class MongoDBManager:
    def __init__(self, connection_string: str = "mongodb://localhost:27017/", db_name: str = "hukum_terbuka_akn"):
        self.connection_string = connection_string
        self.db_name = db_name
        self.async_client = None
        self.db = None
        self.documents_collection = None

    async def connect(self):
        """Connect to MongoDB and initialize db and collection attributes."""
        # Corrected condition:
        if (self.async_client is not None and
                self.db is not None and
                self.documents_collection is not None):
            try:
                await self.async_client.admin.command('ping')
                print(f"✅ MongoDB connection already active for: {self.db_name}")
                return True
            except Exception as e: # Catch specific exceptions if possible
                print(f"Stale connection detected (ping failed: {e}), attempting to reconnect.")
                await self.close() # Close existing (stale) client first, this will nullify attributes

        print(f"Attempting to connect to MongoDB: {self.db_name}...")
        try:
            self.async_client = motor.motor_asyncio.AsyncIOMotorClient(self.connection_string, serverSelectionTimeoutMS=5000)
            await self.async_client.admin.command('ping') # Verify connection
            self.db = self.async_client[self.db_name]
            self.documents_collection = self.db["legal_documents_akn"]
            print(f"✅ Connected to MongoDB: {self.db_name}, collection: {self.documents_collection.name}")
            return True
        except Exception as e:
            print(f"❌ MongoDB connection failed: {e}")
            if self.async_client: # pragma: no cover
                self.async_client.close()
            self.async_client = None
            self.db = None
            self.documents_collection = None
            return False

    async def close(self):
        """Close MongoDB connection and reset attributes."""
        if self.async_client:
            self.async_client.close()
            print("MongoDB connection closed.")
        self.async_client = None
        self.db = None
        self.documents_collection = None

# Initialize MongoDB manager
mongo_manager = MongoDBManager()

# Example of how to connect (will be called later in the main workflow)
# await mongo_manager.connect()

# %%
# Cell 5: Tool Schemas (Revised)
tools_schemas = [
    {
        "type": "function",
        "function": {
            "name": "initialize_akn_document",
            "description": "Initializes a new Akoma Ntoso document skeleton in the database with basic metadata. Should be called only once for a new document, typically when processing the first chunk.",
            "parameters": {
                "type": "object",
                "properties": {
                    "document_id": {"type": "string", "description": "Unique identifier for the document (e.g., UU_8_1961)."},
                    "source_file": {"type": "string", "description": "Filename of the source text document."},
                    "doc_type_hint": {"type": "string", "description": "Hint for the AKN document type (e.g., 'act', 'bill', 'judgment'). Defaults to 'act'."},
                    "initial_metadata": {
                        "type": "object",
                        "description": "Basic metadata extracted from the first part of the document.",
                        "properties": {
                            "title": {"type": "string", "description": "Official title (e.g., 'WAJIB KERJA SARJANA')."},
                            "number": {"type": "string", "description": "Document number (e.g., '8')."},
                            "year": {"type": "string", "description": "Year of the document (e.g., '1961')."},
                            "doc_subtype": {"type": ["string", "null"], "description": "Subtype like 'UNDANG-UNDANG', 'PERATURAN PEMERINTAH'."},
                            "country_code": {"type": "string", "default": "id", "description": "ISO 3166-1 alpha-2 country code, defaults to 'id'."},
                            "author_placeholder": {"type": ["string", "null"], "description": "Placeholder for authoring authority if known."}
                        },
                        "required": ["title", "number", "year", "doc_subtype"]
                    }
                },
                "required": ["document_id", "source_file", "initial_metadata"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "get_akn_document_context",
            "description": "Retrieves parts of the current AKN XML document to provide context to the agent. Can fetch the full document, a specific element by eId, or its parent and siblings.",
            "parameters": {
                "type": "object",
                "properties": {
                    "document_id": {"type": "string", "description": "Unique identifier for the document."},
                    "target_eId": {"type": ["string", "null"], "description": "Optional eId of the element to focus on. If null, might return high-level structure or last modified area."},
                    "context_type": {
                        "type": "string",
                        "enum": ["full", "element_only", "element_with_children", "parent_and_siblings", "element_children_only"],
                        "default": "element_with_children",
                        "description": "Type of context to retrieve if target_eId is specified. 'element_children_only' returns only direct children of the target_eId."
                    },
                    "max_depth": {"type": "integer", "default": 2, "description": "Max depth of children to retrieve if 'element_with_children' is chosen (not used for 'element_children_only')."}
                },
                "required": ["document_id"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "add_akn_element",
            "description": "Adds a new Akoma Ntoso element (as an XML string) as a child of a specified parent element or as a sibling to another element within the document. Handles <content> tag creation for articles/paragraphs if needed.",
            "parameters": {
                "type": "object",
                "properties": {
                    "document_id": {"type": "string", "description": "Unique identifier for the document."},
                    "parent_eId": {"type": ["string","null"], "description": "The eId of the parent element to which the new element will be appended as a child. Use eId of <act> (e.g. 'act') to add top-level elements like preamble, body. If adding to an article's content, provide article's eId."},
                    "new_element_akn_xml": {"type": "string", "description": "The well-formed AKN XML string for the new element to be added. Ensure it's valid XML and adheres to AKN structure."},
                    "sibling_eId": {"type": ["string", "null"], "description": "Optional eId of an existing sibling element. If provided, 'insert_position' determines placement relative to this sibling."},
                    "insert_position": {
                        "type": "string",
                        "enum": ["append_to_parent", "before_sibling", "after_sibling", "append_to_content_of_parent"],
                        "default": "append_to_parent",
                        "description": "Position to insert. 'append_to_parent' adds as last child. 'before_sibling'/'after_sibling' require sibling_eId. 'append_to_content_of_parent' is for adding to <content> of elements like <article> or <paragraph>; it finds/creates <content> under parent_eId and appends there."
                    }
                },
                "required": ["document_id", "new_element_akn_xml"] # parent_eId becomes more crucial depending on insert_position
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "update_akn_element",
            "description": "Updates an existing Akoma Ntoso element in the document. Can update attributes, text content, or append to text content of a suitable child <p> tag.",
            "parameters": {
                "type": "object",
                "properties": {
                    "document_id": {"type": "string", "description": "Unique identifier for the document."},
                    "target_eId": {"type": "string", "description": "The eId of the AKN element to modify. If appending text and this is a structural element, the tool will try to find the last <p> in its <content>."},
                    "new_attributes": {"type": ["object", "null"], "description": "A dictionary of attribute key-value pairs to set/update. E.g. {\"num\": \"(new)\"}."},
                    "new_text_content": {"type": ["string", "null"], "description": "If provided, REPLACES the direct text content of the element. Child elements are removed."},
                    "append_text_content": {"type": ["string", "null"], "description": "If provided, appends this text. If target_eId is a <p> tag, appends to it. If target_eId is a structural element (e.g. <paragraph>, <article>), it tries to append to the text of the LAST <p> child within its <content> element. If no <p> is found, it may append to the target_eId's direct text if appropriate or return an error."}
                },
                "required": ["document_id", "target_eId"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "get_last_p_eId_in_element",
            "description": "Finds the eId of the last <p> element within a specified container element (typically inside its <content>). Useful for appending text accurately.",
            "parameters": {
                "type": "object",
                "properties": {
                    "document_id": {"type": "string", "description": "Unique identifier for the document."},
                    "container_eId": {"type": "string", "description": "The eId of the container element (e.g., a <paragraph> or <article>) to search within."}
                },
                "required": ["document_id", "container_eId"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "store_chunk_processing_info",
            "description": "Stores information about the processing of a specific chunk, including a summary and the eId of the last AKN element significantly handled in that chunk. THIS MUST BE CALLED AT THE END OF PROCESSING EACH CHUNK.",
            "parameters": {
                "type": "object",
                "properties": {
                    "document_id": {"type": "string", "description": "Unique identifier for the document."},
                    "chunk_id": {"type": "string", "description": "Identifier of the processed chunk."},
                    "analysis_summary": {"type": "string", "description": "A brief summary of what was identified and done in this chunk."},
                    "last_processed_akn_eId": {"type": "string", "description": "The eId of the primary Akoma Ntoso element that was last created or modified in this chunk. This helps in resuming context for the next chunk."},
                    "errors_or_notes": {"type": ["string", "null"], "description": "Any errors encountered or specific notes from the agent for this chunk."}
                },
                "required": ["document_id", "chunk_id", "analysis_summary", "last_processed_akn_eId"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "delete_akn_element",
            "description": "Deletes an existing Akoma Ntoso element from the document by its eId. Use this to correct errors where an element was added improperly.",
            "parameters": {
                "type": "object",
                "properties": {
                    "document_id": {"type": "string", "description": "Unique identifier for the document."},
                    "target_eId": {"type": "string", "description": "The eId of the Akoma Ntoso element to be deleted."}
                },
                "required": ["document_id", "target_eId"]
            }
        }
    }
]
print(f"Defined {len(tools_schemas)} tool schemas.")
# Out:
# Defined 7 tool schemas.

# %%
# Cell 6: Tool Implementations (Revised XPath usage)

# --- XML Helper Functions (using lxml) ---
# (parse_xml_string, xml_to_string, find_element_by_eid, find_or_create_content_element - KEEP AS IS from your revised code)
# Ensure AKN_NAMESPACE and NSMAP are defined from Cell 2.

def parse_xml_string(xml_string: str) -> Optional[etree._Element]:
    """Parses an XML string into an lxml Element object."""
    try:
        if not xml_string or not xml_string.strip():
            print("XMLSyntaxError: Input XML string is empty or whitespace.")
            return None
        parser = etree.XMLParser(remove_blank_text=True, strip_cdata=False)
        return etree.fromstring(xml_string.encode('utf-8'), parser=parser)
    except etree.XMLSyntaxError as e:
        print(f"XMLSyntaxError: {e}. Problematic XML: {xml_string[:500]}...")
        return None
    except Exception as e: 
        print(f"Error parsing XML: {e}. XML: {xml_string[:500]}...")
        return None

def xml_to_string(element: etree._Element, pretty_print=True) -> str:
    """Converts an lxml Element object back to a string."""
    if element is None:
        return ""
    return etree.tostring(element, pretty_print=pretty_print, encoding="unicode", xml_declaration=False)

def find_element_by_eid(root: etree._Element, eid: str) -> Optional[etree._Element]:
    """Finds an element by its eId attribute using XPath."""
    if root is None or eid is None:
        return None
    found_elements = root.xpath(f".//*[@eId='{eid}']")
    if found_elements:
        return found_elements[0]
    if root.get("eId") == eid:
        return root
    return None

def find_or_create_content_element(parent_element: etree._Element) -> Optional[etree._Element]:
    """Finds or creates a <content> child element within the given parent."""
    if parent_element is None:
        return None
    content_el = parent_element.find(f"{{{AKN_NAMESPACE}}}content")
    if content_el is None:
        content_el = etree.SubElement(parent_element, etree.QName(AKN_NAMESPACE, "content"))
        parent_eid = parent_element.get("eId")
        # Optional: Give content an eId if desired, e.g.
        # if parent_eid:
        #    content_el.set("eId", f"{parent_eid}__content") 
    return content_el

# --- Tool Implementations ---
TOOL_MAPPING = {}

# initialize_akn_document (KEEP AS IS from your revised code in the previous turn)
async def initialize_akn_document(document_id: str, source_file: str, doc_type_hint: str = "act", initial_metadata: dict = None) -> str: # Changed default to 'act' (lowercase)
    if mongo_manager.documents_collection is None:
        return "Error: MongoDB not connected or collection not initialized."
    if initial_metadata is None:
        initial_metadata = {}

    existing_doc = await mongo_manager.documents_collection.find_one({"document_id": document_id})
    if existing_doc:
        return f"Error: Document {document_id} already exists. Cannot re-initialize. Delete it first if a fresh start is intended."

    akn_root = etree.Element(etree.QName(AKN_NAMESPACE, "akomaNtoso"), nsmap=NSMAP)
    
    # Use lowercase for doc_element_tag and its eId
    doc_element_tag = doc_type_hint.lower() # e.g., "act"
    doc_el_eid = doc_element_tag # e.g., eId="act"
    
    doc_el = etree.SubElement(akn_root, etree.QName(AKN_NAMESPACE, doc_element_tag.lower()), eId=doc_el_eid) # Tag is <ACT>, eId is "act"
    doc_el.set("name", "indonesianAct") 

    # Consistently use lowercase prefix for eIds of direct children of the main doc element
    meta_el = etree.SubElement(doc_el, etree.QName(AKN_NAMESPACE, "meta"), eId=f"{doc_el_eid}__meta")
    identification_el = etree.SubElement(meta_el, etree.QName(AKN_NAMESPACE, "identification"), eId=f"{doc_el_eid}__meta__identification", source="#sourceSystem")

    frbr_work_el = etree.SubElement(identification_el, etree.QName(AKN_NAMESPACE, "FRBRWork"), eId=f"{doc_el_eid}__meta__identification__work")
    year = initial_metadata.get("year", "0000")
    number = initial_metadata.get("number", "0")
    title = initial_metadata.get("title", "Unknown Title")
    country = initial_metadata.get("country_code", "id")
    # doc_subtype_for_uri should be like 'undang-undang', 'peraturan-pemerintah'
    doc_subtype_raw = initial_metadata.get("doc_subtype", doc_element_tag) # Fallback to "act" if not provided
    doc_subtype_for_uri = doc_subtype_raw.lower().replace(" ", "-")


    etree.SubElement(frbr_work_el, etree.QName(AKN_NAMESPACE, "FRBRthis"), value=f"/akn/{country}/{doc_subtype_for_uri}/{year}/{number}/main")
    etree.SubElement(frbr_work_el, etree.QName(AKN_NAMESPACE, "FRBRuri"), value=f"/akn/{country}/{doc_subtype_for_uri}/{year}/{number}")
    etree.SubElement(frbr_work_el, etree.QName(AKN_NAMESPACE, "FRBRdate"), date=f"{year}-01-01", name="creation") 
    etree.SubElement(frbr_work_el, etree.QName(AKN_NAMESPACE, "FRBRauthor"), href="#system", as_="#author")
    etree.SubElement(frbr_work_el, etree.QName(AKN_NAMESPACE, "FRBRcountry"), value=country)
    if title:
        etree.SubElement(frbr_work_el, etree.QName(AKN_NAMESPACE, "FRBRname"), value=str(title))
    if number:
        etree.SubElement(frbr_work_el, etree.QName(AKN_NAMESPACE, "FRBRnumber"), value=str(number))

    frbr_manifestation_el = etree.SubElement(identification_el, etree.QName(AKN_NAMESPACE, "FRBRManifestation"), eId=f"{doc_el_eid}__meta__identification__manifestation")
    # Option to include publication date in URI (align with mapping doc opinion if desired)
    # current_date_for_uri = datetime.now(timezone.utc).strftime("%Y-%m-%d")
    # etree.SubElement(frbr_manifestation_el, etree.QName(AKN_NAMESPACE, "FRBRthis"), value=f"/akn/{country}/{doc_subtype_for_uri}/{year}/{number}/id@{current_date_for_uri}/main.xml")
    # etree.SubElement(frbr_manifestation_el, etree.QName(AKN_NAMESPACE, "FRBRuri"), value=f"/akn/{country}/{doc_subtype_for_uri}/{year}/{number}/id@{current_date_for_uri}.xml")
    # Current implementation from your notebook:
    etree.SubElement(frbr_manifestation_el, etree.QName(AKN_NAMESPACE, "FRBRthis"), value=f"/akn/{country}/{doc_subtype_for_uri}/{year}/{number}/id@main.xml") 
    etree.SubElement(frbr_manifestation_el, etree.QName(AKN_NAMESPACE, "FRBRuri"), value=f"/akn/{country}/{doc_subtype_for_uri}/{year}/{number}/id.xml")
    etree.SubElement(frbr_manifestation_el, etree.QName(AKN_NAMESPACE, "FRBRdate"), date=datetime.now(timezone.utc).strftime("%Y-%m-%d"), name="publication")
    etree.SubElement(frbr_manifestation_el, etree.QName(AKN_NAMESPACE, "FRBRformat"), value="application/akn+xml")

    # Create main structural children with consistent lowercase eId prefixes
    etree.SubElement(doc_el, etree.QName(AKN_NAMESPACE, "preamble"), eId=f"{doc_el_eid}__preamble")
    etree.SubElement(doc_el, etree.QName(AKN_NAMESPACE, "body"), eId=f"{doc_el_eid}__body")
    etree.SubElement(doc_el, etree.QName(AKN_NAMESPACE, "conclusions"), eId=f"{doc_el_eid}__conclusions")
    etree.SubElement(doc_el, etree.QName(AKN_NAMESPACE, "attachments"), eId=f"{doc_el_eid}__attachments")
    
    akn_xml_string = xml_to_string(akn_root)

    doc_to_insert = {
        "document_id": document_id,
        "source_file": source_file,
        "document_metadata_extracted": initial_metadata,
        "akn_xml_string": akn_xml_string,
        "processing_state": {
            "current_chunk_id": None,
            "last_processed_akn_eId": doc_el_eid, # e.g., "act"
            "status": "initialized"
        },
        "chunk_processing_log": [],
        "created_at": datetime.now(timezone.utc),
        "updated_at": datetime.now(timezone.utc)
    }
    try:
        await mongo_manager.documents_collection.insert_one(doc_to_insert)
        return f"Successfully initialized Akoma Ntoso document '{document_id}' in database. Root eId: '{doc_el_eid}'."
    except Exception as e:
        return f"Error initializing document '{document_id}': {str(e)}"
TOOL_MAPPING["initialize_akn_document"] = initialize_akn_document

# get_akn_document_context (KEEP AS IS from your revised code in the previous turn)
async def get_akn_document_context(document_id: str, target_eId: Optional[str] = None,
                                   context_type: str = "element_with_children",
                                   max_depth: int = 2) -> str:
    if mongo_manager.documents_collection is None:
        return "Error: MongoDB not connected or collection not initialized."

    doc_data = await mongo_manager.documents_collection.find_one({"document_id": document_id})
    if not doc_data or "akn_xml_string" not in doc_data:
        return f"Error: Document '{document_id}' not found or has no AKN XML."

    akn_xml_string = doc_data["akn_xml_string"]
    root = parse_xml_string(akn_xml_string)
    if root is None:
        return "Error: Could not parse stored AKN XML."

    if context_type == "full":
        return xml_to_string(root)

    if not target_eId:
        # If no target_eId, return summary of the main document element (e.g. ACT)
        main_doc_element = root[0] if len(root) > 0 else root 
        if main_doc_element is not None:
            summary_context = etree.Element(main_doc_element.tag, nsmap=NSMAP, attrib=main_doc_element.attrib)
            for child in main_doc_element:
                if child.tag.endswith("meta") or child.tag.endswith("preamble") or \
                   child.tag.endswith("body") or child.tag.endswith("conclusions") or \
                   child.tag.endswith("attachments"):
                    child_copy = etree.Element(child.tag, nsmap=NSMAP, attrib=child.attrib)
                    # Optionally add 1 level of children for a bit more context
                    # for sub_child in child:
                    #     sub_child_copy = etree.Element(sub_child.tag, nsmap=NSMAP, attrib=sub_child.attrib)
                    #     child_copy.append(sub_child_copy)
                    summary_context.append(child_copy)
            return xml_to_string(summary_context) if len(summary_context) > 0 else xml_to_string(main_doc_element)
        return xml_to_string(root) 

    element_to_focus = find_element_by_eid(root, target_eId)
    if element_to_focus is None:
        return f"Error: Element with eId '{target_eId}' not found in document '{document_id}'. Check eId or use a known parent."

    if context_type == "element_only":
        return xml_to_string(element_to_focus)
    
    elif context_type == "element_with_children":
        return xml_to_string(element_to_focus) # Returns element and its full subtree
        
    elif context_type == "element_children_only":
        # Create a temporary wrapper to hold copies of children
        children_wrapper = etree.Element(etree.QName(AKN_NAMESPACE, "childrenContext"), nsmap=NSMAP)
        for child in element_to_focus:
            # Deepcopy each child to avoid modifying the original tree if the snippet is altered
            children_wrapper.append(etree.fromstring(etree.tostring(child))) 
        return xml_to_string(children_wrapper)

    elif context_type == "parent_and_siblings":
        parent = element_to_focus.getparent()
        if parent is None: 
            return xml_to_string(element_to_focus) # Target is root or has no parent in this view
        
        parent_copy_for_context = etree.fromstring(etree.tostring(parent))
        return xml_to_string(parent_copy_for_context)

    return f"Error: Invalid context_type '{context_type}' or other issue with target_eId."
TOOL_MAPPING["get_akn_document_context"] = get_akn_document_context

# add_akn_element (KEEP AS IS from your revised code in the previous turn)
async def add_akn_element(document_id: str, new_element_akn_xml: str,
                          parent_eId: Optional[str] = None,
                          sibling_eId: Optional[str] = None,
                          insert_position: str = "append_to_parent") -> str:
    if mongo_manager.documents_collection is None:
        return "Error: MongoDB not connected or collection not initialized."

    doc_data = await mongo_manager.documents_collection.find_one({"document_id": document_id})
    if not doc_data or "akn_xml_string" not in doc_data:
        return f"Error: Document '{document_id}' not found."

    current_xml_str = doc_data["akn_xml_string"]
    root = parse_xml_string(current_xml_str)
    if root is None: return "Error: Could not parse stored AKN XML."

    try:
        new_element = parse_xml_string(new_element_akn_xml)
        if new_element is None: return f"Error: Could not parse new_element_akn_xml: {new_element_akn_xml[:100]}"
    except Exception as e:
        return f"Error parsing new_element_akn_xml: {str(e)}. Snippet: {new_element_akn_xml[:100]}"

    new_element_eId_attr = new_element.get("eId")
    if not new_element_eId_attr:
        # Allow adding elements without eId if they are simple like <p> inside a complex structure being added all at once.
        # However, top-level structural elements added individually should have eIds.
        # For now, this check is for elements directly added by this tool call.
        # If the agent is providing a large XML blob with many nested elements, only the top one needs an eId here.
        # This logic might need refinement based on how the agent uses the tool.
        # A simpler rule: if the `new_element_akn_xml` represents a single new block, it should have an eId.
        # If it's a <p> tag, it MIGHT not need an eId if its parent structure provides uniqueness.
        # Let's assume for now, direct adds of structural items need an eId.
        if etree.QName(new_element.tag).localname not in ['p', 'num', 'heading']: # Allow p, num, heading without eId if part of larger add
             return f"Error: New element XML is missing an 'eId' attribute for structural element. XML: {new_element_akn_xml[:200]}"
    elif find_element_by_eid(root, new_element_eId_attr) is not None:
        return f"Error: Element with eId '{new_element_eId_attr}' already exists in the document. Cannot add duplicate."

    target_parent_for_ops = None # This will be the element to which the new_element is appended or related

    if insert_position == "append_to_parent" or insert_position == "append_to_content_of_parent":
        if not parent_eId: return f"Error: parent_eId is required for '{insert_position}'."
        
        target_parent_for_ops = find_element_by_eid(root, parent_eId)
        if target_parent_for_ops is None: return f"Error: Parent element with eId '{parent_eId}' not found."

        if insert_position == "append_to_content_of_parent":
            parent_tag_name = etree.QName(target_parent_for_ops.tag).localname
            # Common AKN elements that typically wrap their main textual/block content in a <content> tag
            content_holder_tags = ["article", "paragraph", "clause", "recital", "citation", 
                                   "speech", "question", "answer", "other", "scene", "point", "item",
                                   "chapter", "section", "subsection", "alinea"] # Added more
            if parent_tag_name in content_holder_tags:
                content_element = find_or_create_content_element(target_parent_for_ops)
                if content_element is None: 
                    return f"Error: Could not find or create <content> in parent eId '{parent_eId}'."
                content_element.append(new_element)
            else: # If not a typical content holder, or if agent wants direct append.
                target_parent_for_ops.append(new_element)
        else: # append_to_parent
            target_parent_for_ops.append(new_element)

    elif insert_position in ["before_sibling", "after_sibling"]:
        if not sibling_eId: return f"Error: sibling_eId is required for '{insert_position}'."
        # Parent_eId is the parent of the sibling, crucial for context.
        if not parent_eId: return f"Error: parent_eId (of the sibling) is required for '{insert_position}'."

        actual_parent_of_sibling = find_element_by_eid(root, parent_eId)
        if actual_parent_of_sibling is None: return f"Error: Specified parent element '{parent_eId}' (for sibling) not found."
        
        target_sibling = find_element_by_eid(actual_parent_of_sibling, sibling_eId) 
        if target_sibling is None: return f"Error: Sibling element with eId '{sibling_eId}' not found under parent '{parent_eId}'."
        
        if target_sibling.getparent() is None or target_sibling.getparent() != actual_parent_of_sibling :
             return f"Error: Sibling element '{sibling_eId}' is not a direct child of parent '{parent_eId}'."

        if insert_position == "before_sibling":
            target_sibling.addprevious(new_element)
        else: 
            target_sibling.addnext(new_element)
    else:
        return f"Error: Invalid insert_position '{insert_position}'."

    updated_xml_str = xml_to_string(root)
    try:
        await mongo_manager.documents_collection.update_one(
            {"document_id": document_id},
            {"$set": {"akn_xml_string": updated_xml_str, "updated_at": datetime.now(timezone.utc)}}
        )
        # Use new_element_eId_attr if available, otherwise the tag name for confirmation
        confirmation_id = new_element_eId_attr if new_element_eId_attr else etree.QName(new_element.tag).localname
        return f"Successfully added element '{confirmation_id}' to document '{document_id}'."
    except Exception as e:
        return f"Error updating document in DB after adding element: {str(e)}"
TOOL_MAPPING["add_akn_element"] = add_akn_element

# update_akn_element (Revised XPath)
async def update_akn_element(document_id: str, target_eId: str,
                             new_attributes: Optional[dict] = None,
                             new_text_content: Optional[str] = None,
                             append_text_content: Optional[str] = None) -> str:
    if mongo_manager.documents_collection is None:
        return "Error: MongoDB not connected or collection not initialized."

    doc_data = await mongo_manager.documents_collection.find_one({"document_id": document_id})
    if not doc_data or "akn_xml_string" not in doc_data:
        return f"Error: Document '{document_id}' not found."

    current_xml_str = doc_data["akn_xml_string"]
    root = parse_xml_string(current_xml_str)
    if root is None: return "Error: Could not parse stored AKN XML."

    target_element = find_element_by_eid(root, target_eId)
    if target_element is None: return f"Error: Element with eId '{target_eId}' not found."

    updated = False
    if new_attributes:
        for key, value in new_attributes.items():
            target_element.set(key, str(value))
        updated = True

    if new_text_content is not None:
        # Clear existing children and direct text before setting new text
        target_element.text = None # Clear direct text
        for child in list(target_element): # Iterate over a copy for safe removal
            target_element.remove(child)
        
        # The new_text_content is usually wrapped in a <p> by the agent if it's block text.
        # If the agent provides raw text for an element that should contain <p>, this logic might need adjustment.
        # For now, assume new_text_content is the direct text for the target_element if it's a simple text node,
        # or the agent provides structured XML (like a <p>) if target_element is a container.
        # The prompt should guide the agent to provide <p> wrapped text for content holders.
        # A safer way if new_text_content is meant to be the *sole* content for e.g. a paragraph:
        # Create a <p> element, set its text, and append it to a <content> element.
        # However, current schema says "replaces the direct text content".

        # Let's assume agent provides text for a <p> or similar, or for a structural element it intends to make simple text.
        # If it's for a structural element and meant to be paragraph content, agent should provide `<p>text</p>` as new_text_content.
        # A simple `target_element.text = new_text_content` is okay if `target_element` itself is the text carrier (e.g. <p>, <num>).
        # If target_element is structural (e.g. <paragraph eid="X">), setting its text directly is usually wrong.
        # The tool should ideally parse new_text_content if it's XML or place it correctly.

        # Current implementation of update_akn_element as per schema, `new_text_content` replaces direct text.
        # If target_eId is e.g. a <paragraph>, and agent passes "New text", the XML becomes <paragraph>New text</paragraph> (children removed).
        # This is often NOT what is desired for structural elements.
        # The agent should provide XML like "<content><p>New text</p></content>" as `new_element_akn_xml` to `add_akn_element` (by first deleting the old content if replacement is intended)
        # OR, `update_akn_element` needs a parameter like `replace_children_with_xml_string`.
        # For now, adhering to "replaces the direct text content":
        target_element.text = new_text_content
        target_element.tail = None
        updated = True


    if append_text_content:
        element_to_append_to = target_element
        target_tag_name = etree.QName(target_element.tag).localname
        
        # If target is structural, try to find the last <p> in its <content> or directly.
        if target_tag_name not in ["p", "heading", "num", "td", "th", "caption"]: # e.g. article, paragraph
            # Try to find <content> then last <p> inside it
            content_el = target_element.find(f"{{{AKN_NAMESPACE}}}content")
            if content_el is not None:
                # Corrected XPath with namespace map
                last_p_elements = content_el.xpath(f".//akn:p[last()]", namespaces={'akn': AKN_NAMESPACE})
                if last_p_elements:
                    element_to_append_to = last_p_elements[0]
                else: # No <p> in <content>, append to <content>'s text? Or create <p>?
                      # For now, if no <p>, this logic doesn't change element_to_append_to from target_element
                      # Agent should ensure <p> exists or use `get_last_p_eId_in_element`
                      pass 
            else: # No <content> element, try to find last <p> directly in target_element
                last_p_elements = target_element.xpath(f"./akn:p[last()] | .//akn:p[last()]", namespaces={'akn': AKN_NAMESPACE}) # Check direct children first, then descendants
                if last_p_elements:
                    element_to_append_to = last_p_elements[0]
        
        # Append text to the determined element
        if element_to_append_to.text:
            element_to_append_to.text += append_text_content
        else:
            element_to_append_to.text = append_text_content
        updated = True
    
    if not updated and not new_attributes and new_text_content is None and append_text_content is None:
        return f"Info: No update operation specified for element '{target_eId}'."

    updated_xml_str = xml_to_string(root)
    try:
        await mongo_manager.documents_collection.update_one(
            {"document_id": document_id},
            {"$set": {"akn_xml_string": updated_xml_str, "updated_at": datetime.now(timezone.utc)}}
        )
        return f"Successfully updated element '{target_eId}' in document '{document_id}'."
    except Exception as e:
        return f"Error updating document '{document_id}' in DB after updating element: {str(e)}"
TOOL_MAPPING["update_akn_element"] = update_akn_element

# get_last_p_eId_in_element (Revised XPath)
async def get_last_p_eId_in_element(document_id: str, container_eId: str) -> str:
    if mongo_manager.documents_collection is None:
        return "Error: MongoDB not connected or collection not initialized."

    doc_data = await mongo_manager.documents_collection.find_one({"document_id": document_id})
    if not doc_data or "akn_xml_string" not in doc_data:
        return f"Error: Document '{document_id}' not found or has no AKN XML."

    akn_xml_string = doc_data["akn_xml_string"]
    root = parse_xml_string(akn_xml_string)
    if root is None:
        return "Error: Could not parse stored AKN XML."

    container_element = find_element_by_eid(root, container_eId)
    if container_element is None:
        return f"Error: Container element with eId '{container_eId}' not found."

    # Corrected XPath: Find <p> descendants of the container_element and take the last one.
    # Explicitly use the namespace.
    try:
        # Search within <content> if it exists, otherwise directly in container
        content_el = container_element.find(f"{{{AKN_NAMESPACE}}}content")
        search_context = content_el if content_el is not None else container_element
        
        # Find the last <p> element that is a descendant of search_context
        last_p_elements = search_context.xpath(".//akn:p[last()]", namespaces={'akn': AKN_NAMESPACE})
    except etree.XPathEvalError as e:
        return f"Error: XPath evaluation error in get_last_p_eId_in_element for '{container_eId}': {e}"

    if last_p_elements:
        last_p_eId = last_p_elements[0].get("eId")
        if last_p_eId:
            return f"Success: eId of last <p> in '{container_eId}' is '{last_p_eId}'."
        else:
            # If last <p> has no eId, we can't return an eId.
            # Agent might need to add an eId to it first or target the container for append.
            p_text_preview = (last_p_elements[0].text or "")[:30]
            return f"Info: Last <p> element in '{container_eId}' found, but it has no eId. Preview: '{p_text_preview}...'"
    else:
        return f"Info: No <p> elements found within container '{container_eId}' (or its <content> child)."
TOOL_MAPPING["get_last_p_eId_in_element"] = get_last_p_eId_in_element

# store_chunk_processing_info (KEEP AS IS from your revised code)
async def store_chunk_processing_info(document_id: str, chunk_id: str,
                                      analysis_summary: str, last_processed_akn_eId: str,
                                      errors_or_notes: Optional[str] = None) -> str:
    if mongo_manager.documents_collection is None:
        return "Error: MongoDB not connected or collection not initialized."

    log_entry = {
        "chunk_id": chunk_id,
        "analysis_summary": analysis_summary,
        "last_processed_akn_eId_at_end_of_chunk": last_processed_akn_eId,
        "errors_or_notes": errors_or_notes,
        "timestamp": datetime.now(timezone.utc)
    }
    
    update_query = {
        "$push": {"chunk_processing_log": log_entry},
        "$set": {
            "processing_state.current_chunk_id": chunk_id,
            "processing_state.last_processed_akn_eId": last_processed_akn_eId,
            "processing_state.status": "processing", 
            "updated_at": datetime.now(timezone.utc)
        }
    }
    doc_exists_count = await mongo_manager.documents_collection.count_documents({"document_id": document_id}, limit=1)
    if doc_exists_count == 0:
        return f"Error: Document '{document_id}' not found. Cannot store chunk info. Was it initialized?"
        
    try:
        result = await mongo_manager.documents_collection.update_one(
            {"document_id": document_id},
            update_query
        )
        if result.matched_count == 0: 
            return f"Error: Document '{document_id}' not found for storing chunk info (race condition?)."
        # modified_count can be 0 if only $push happened to an existing array field and no $set fields changed value
        # So, successful match is a better indicator here for $push.
        return f"Successfully stored processing info for chunk '{chunk_id}' of document '{document_id}'. Last eId set to '{last_processed_akn_eId}'."
    except Exception as e:
        return f"Error storing chunk processing info for '{document_id}': {str(e)}"
TOOL_MAPPING["store_chunk_processing_info"] = store_chunk_processing_info

async def delete_akn_element(document_id: str, target_eId: str) -> str:
    """
    Deletes an Akoma Ntoso element from the XML document stored in MongoDB.
    """
    if mongo_manager.documents_collection is None:
        return "Error: MongoDB not connected or collection not initialized."

    doc_data = await mongo_manager.documents_collection.find_one({"document_id": document_id})
    if not doc_data or "akn_xml_string" not in doc_data:
        return f"Error: Document '{document_id}' not found or has no AKN XML."

    current_xml_str = doc_data["akn_xml_string"]
    root = parse_xml_string(current_xml_str)
    if root is None:
        return "Error: Could not parse stored AKN XML."

    element_to_delete = find_element_by_eid(root, target_eId)
    if element_to_delete is None:
        return f"Error: Element with eId '{target_eId}' not found in document '{document_id}'. Cannot delete."

    parent = element_to_delete.getparent()
    if parent is None:
        # This might mean the element_to_delete is the root of a detached tree fragment,
        # or it's the document's root element itself. Deleting the main doc root is usually not intended.
        # For now, let's prevent deletion of the direct children of <akomaNtoso> (i.e., the <ACT>, <BILL> etc.)
        # or the <akomaNtoso> root itself if target_eId pointed to it.
        if element_to_delete.getparent() is None and element_to_delete is root: # Trying to delete <akomaNtoso>
             return f"Error: Cannot delete the root <akomaNtoso> element '{target_eId}'."
        if element_to_delete.getparent() is root and etree.QName(root.tag).localname == "akomaNtoso": # Trying to delete <ACT>, etc.
             if len(root) <= 1: # If it's the only child of akomaNtoso
                  return f"Error: Cannot delete the main document element '{target_eId}' as it's the only top-level structure."
        # If it's a detached element somehow found by eId but not in main tree, this is complex.
        # For robust safety, one might restrict deletion to elements with actual parents unless explicitly allowed.
        # However, find_element_by_eid should find it within the `root` tree.
        # The main risk is trying to delete the <ACT> element itself or its primary children like <meta>, <body>
        # if they were targeted by mistake.
        # A simple check: if parent is the root <akomaNtoso> element, be cautious.
        # Let's assume for now that if an element is found, it can be removed from its parent.
        # If an element is the root of the parsed string (e.g., <ACT>), .getparent() would be None.
        # Deleting the main <ACT> (or similar) element is generally not desired through this tool.
        # The find_element_by_eid searches *within* the root provided.
        # So if root is <akomaNtoso>, and target_eId is the <ACT> element, parent will be <akomaNtoso>.
        # If root is the <ACT> element itself, then its parent is None relative to that parsing.
        # Let's assume the 'root' from parse_xml_string is always <akomaNtoso>.
        # And find_element_by_eid works on its children.
        pass # Allow deletion if parent is found. If parent is None, it's an issue below.

    if parent is not None:
        try:
            parent.remove(element_to_delete)
            updated_xml_str = xml_to_string(root)
            await mongo_manager.documents_collection.update_one(
                {"document_id": document_id},
                {"$set": {"akn_xml_string": updated_xml_str, "updated_at": datetime.now(timezone.utc)}}
            )
            return f"Successfully deleted element '{target_eId}' from document '{document_id}'."
        except Exception as e:
            return f"Error during removal or DB update for element '{target_eId}': {str(e)}"
    else:
        # This case means element_to_delete was likely the root element passed to find_element_by_eid,
        # or it's a part of a malformed structure. Deleting the entire document root (e.g., <ACT>) this way is risky.
        # The `initialize_akn_document` creates the <ACT eId="ACT">. If target_eId="ACT", this would be it.
        # The prompt should guide the agent not to delete foundational elements like "ACT", "ACT__meta", "ACT__body" etc.
        # unless it's a very specific recovery scenario.
        if element_to_delete is root[0] and etree.QName(root.tag).localname == "akomaNtoso": # e.g. deleting the <ACT> element
            return f"Error: Cannot delete the main document container element '{target_eId}' using this tool. Re-initialization might be needed for such a change."
        return f"Error: Element '{target_eId}' found but has no parent in the current XML structure, or it is the root document element. Deletion aborted for safety."

TOOL_MAPPING["delete_akn_element"] = delete_akn_element

print(f"Defined {len(TOOL_MAPPING)} tool implementations with revisions.")
# Out:
# Defined 7 tool implementations with revisions.

# %%
# Cell 7: Agent System Prompt (Revised)

# Ensure AKN_STRUCTURE_MAPPING_INFO is defined from Cell 2.
agent_system_prompt = f"""
You are an expert legislative informatics assistant specializing in converting Indonesian legal documents into Akoma Ntoso (AKN) v3.0 XML format.
Your primary goal is to analyze chunks of an Indonesian legal text and incrementally construct a well-formed and semantically rich Akoma Ntoso XML document.
You MUST strictly adhere to Akoma Ntoso structure and use the provided mappings and eId strategy.
The document will be built incrementally. Always consider the current state of the AKN XML document and the context of the last processed element.

### New Emphasis: Textual Accuracy and Correction
**Crucial Task - Textual Fidelity:** Before incorporating text into AKN elements, you MUST meticulously review it for OCR errors, spelling mistakes, grammatical inaccuracies, and awkward phrasing carried over from the source.
* Correct common OCR errors (e.g., "setiaporang" to "setiap orang", "Pemerintah mengalami kekurangan akan tenaga sarjana" to "Pemerintah mengalami kekurangan tenaga sarjana").
* Ensure proper Indonesian grammar and spelling (EYD/PUEBI).
* Resolve run-on words or incorrectly split words. But be careful, some words or terms may be intentionally that way, e.g. "azas" and "asas" can be used interchangeably, "berbagai" and "perbagai", etc. 
* Identify and reconcile near-duplicate text segments that might arise from OCR or formatting issues in the source, especially when appending text.
* When you make a correction, briefly note the correction in your reasoning before calling the tool. For example: "Corrected 'pasal5ayat' to 'pasal 5 ayat'. Incorporating corrected text into a new <p> element."
* The goal is clean, accurate, and readable text within the XML, while preserving the original legal meaning.
* **CRITICAL FOR REFERENCES:** When forming references like 'Pasal X ayat (Y) huruf z', ensure correct spacing and parentheses: 'Pasal 1 ayat (4)', NOT 'Pasal 1 ayat4)'. Double-check this carefully.
* **XML COMPLETENESS:** When generating `new_element_akn_xml` for tools, ensure the XML is complete and does not end abruptly. Double-check that sentences and lists within the XML are fully formed before calling the tool.

**Core Task:**
For each chunk of text provided:
1.  Analyze the text to identify its structural and semantic meaning. Consider potential variations from standard structure.
2.  Determine how this text fits into the existing Akoma Ntoso XML document structure. Pay attention to document type nuances.
3.  Construct appropriate Akoma Ntoso XML snippet(s). Generated XML snippets MUST be well-formed and have unique `eId` attributes for new elements. Ensure generated XML is not prematurely truncated.
4.  Use the available tools strategically:
    * **`initialize_akn_document`**:
        * Call ONLY for the very first chunk if the document isn't initialized. Provide `doc_type_hint="act"` for Undang-Undang.
        * This creates the main document element (e.g., `<ACT eId="act">`) and its primary children (`<meta eId="act__meta">`, `<preamble eId="act__preamble">`, `<body eId="act__body">`, etc.).
        * **IMPORTANT**: After initialization, use these specific `eId`s (e.g., `act__body`, `act__preamble`) as `parent_eId`s.
    * **`get_akn_document_context`**: CRITICAL.
        * Fetch context of `last_processed_akn_eId` or its parent before adding/updating.
        * Verify existence of parent elements and examine current children for correct numbering/placement.
        * **Crucial for Appending Text**: Before appending text to a `<p>` or similar element, retrieve its full current text to ensure seamless continuation.
    * **`add_akn_element`**:
        * For new structural elements (Pasal, Ayat, list items, containers).
        * When adding content like a `<p>` or a `<list>` inside an `<article>` or `<paragraph>`, use `insert_position='append_to_content_of_parent'` with the `parent_eId` of the `<article>` or `<paragraph>`. The tool will handle finding/creating the necessary `<content>` wrapper.
        * Ensure `new_element_akn_xml` has a unique `eId` for new structural blocks.
    * **`update_akn_element`**:
        * For modifying attributes or replacing text.
        * For `append_text_content`:
            * **Overlap Handling**: First, use `get_akn_document_context` to retrieve the *full current text* of the target paragraph. Carefully compare the end of the existing text with the beginning of the new chunk's relevant text. You MUST remove any duplicated/overlapping portion from the *new text to be appended* before calling the tool. For example, if existing text ends with "...menurut pera" and the new chunk continues with "peraturan ini.", the `append_text_content` should be "turan ini." (after corrections), not the full "peraturan ini.".
            * If target is structural (e.g., `<paragraph eId="X">`), tool appends to last `<p>` in its `<content>`.
        * **Clarification for `new_text_content`**: If using `new_text_content` to replace the content of a structural element like `<paragraph eId="X">`, and you intend to set its textual content, you should target the inner `<p>` tag (e.g., `act__body__art_1__para_1__p_1` if it exists and has an eId) OR consider deleting old content and adding new, correctly structured content using `add_akn_element`. Directly setting `new_text_content` on `paragraph` itself will replace its children, which may not be desired.
    * **`delete_akn_element`**:
        * Use this tool to remove an element that was added incorrectly (e.g., wrong eId, wrong location, duplicated).
        * After deleting, re-evaluate and use `add_akn_element` or `update_akn_element` correctly. Do not delete and re-add with the exact same error.
    * **`get_last_p_eId_in_element`**: Use to find `eId` of last `<p>` if `update_akn_element` on container eId isn't precise enough for appending.
5.  **MANDATORY FINAL STEP FOR EACH CHUNK:** Call `store_chunk_processing_info` with an accurate `last_processed_akn_eId`.

**Akoma Ntoso Mapping and `eId` Strategy Details:**
The root document element (e.g., for an Act) should have `eId="act"`. All its direct children (`meta`, `preamble`, `body`, `conclusions`, `attachments`) MUST have `eId`s like `act__meta`, `act__preamble`, `act__body`, etc. Subsequent nested elements follow this lowercase hierarchical pattern: `act__body__art_1`, `act__body__art_1__para_1`, `act__elucidation_1__body__elucArtByArt_1__art_1`, etc.
{AKN_STRUCTURE_MAPPING_INFO}

### Handling Structural Variations & Specific Guidance:
* **`<num>` Element Text Content:** The text content of `<num>` elements for Pasal, Bab, etc., (e.g., `<num>Pasal 1</num>`, `<num>BAB I</num>`) MUST NOT include a trailing dot. The `num` *attribute* also must not include the dot or the word "Pasal/Bab".
* Preamble - Menimbang/Mengingat Headings: For `<recitals>` (Menimbang) and `<citations>` (Mengingat), if the source text's heading (e.g., "Menimbang:") is inherently represented by the AKN element itself, do NOT create an additional child `<heading>` tag for that specific phrase.
* Elucidation Preface Title: The preface of an elucidation (within `<attachment type="elucidation">`) should typically contain a single, comprehensive `<docTitle>` element for the elucidation's full title (e.g., `<docTitle>PENJELASAN ATAS UNDANG-UNDANG NOMOR X TAHUN YYYY TENTANG ZZZ</docTitle>`). Avoid multiple `<p>` tags or fragmented title components in the preface.
* Metadata - Lembaran Negara (LN) & Tambahan Lembaran Negara (TLN):
    * The primary Lembaran Negara (LN) details for the main act should be stored in `<meta><publication eId="act__meta__publication_ln_YYYY_NN" name="LembaranNegara" ... /></meta>`. Update its attributes (`date`, `number`, `showAs`) as needed. Ensure the `eId` includes the year and number.
    * Any "Tambahan Lembaran Negara" (TLN) information should be added as a *separate* `<publication eId="act__meta__publication_tln_YYYY_NN" name="TambahanLembaranNegara" ... />` element within `<meta>`. Ensure `eId`s for these are distinct and follow a pattern (e.g., `act__meta__tln_YYYY_NNNN`).

**Workflow Example (Conceptual for adding content to `body` after initialization):**
* User provides Chunk 1. Document state: `last_processed_akn_eId="act"` (from `initialize_akn_document`).
* You (Agent):
    1.  "Analyzing Chunk 1. Text starts with 'Pasal 1...'. Document ID is 'doc_X', previous eId 'act'."
    2.  "Text quality check: Corrected 'Pasal1' to 'Pasal 1'. The content seems to be a standard article."
    3.  "Since 'act' is the root, I need to add this Pasal to the main body. The initialized body eId is 'act__body'."
    4.  "I will construct the AKN for Pasal 1: `<article eId=\\"act__body__art_1\\" num=\\"1\\"><num>Pasal 1</num><content><p>Corrected text...</p></content></article>`." (Ensuring no trailing dot in `<num>Pasal 1</num>`)
    5.  "I will call `add_akn_element` with `parent_eId='act__body'`, `new_element_akn_xml` for the article, `insert_position='append_to_parent'`."
    6.  (Tool confirms success)
    7.  "The main element processed is `act__body__art_1`."
    8.  "Calling `store_chunk_processing_info` with `last_processed_akn_eId='act__body__art_1'`."

**Important Rules for Interaction:**
* **eIds:** Generate carefully, hierarchically, unique. Base eIds like `act__preamble`, `act__body` are established by `initialize_akn_document` (with the `act__` prefix).
* **Error Handling:** If a tool call returns an error: Analyze it. Do NOT blindly retry. Use `get_akn_document_context` to re-verify structure. If an element was added incorrectly, consider using `delete_akn_element` before attempting to re-add.
* **XML Validity:** Ensure XML provided to tools is well-formed and not truncated.
* **Reasoning:** Clearly articulate analysis, text corrections, AKN structuring plan, and tool calls.

Your response should primarily be a sequence of tool calls. Explain your reasoning briefly but clearly.
"""
print("Agent system prompt defined.")
# Out:
# Agent system prompt defined.

# %%
def simple_chunk_text(text: str, chunk_size: int = 2000, overlap: int = 500) -> List[Dict[str, Any]]:
    """
    Simple chunking function that splits text every chunk_size characters
    with optional overlap to maintain context.
    """
    chunks_data = []
    start = 0
    chunk_id_counter = 1

    while start < len(text):
        end = start + chunk_size
        chunk_text = text[start:end]

        chunks_data.append({
            "chunk_id": f"chunk_{chunk_id_counter:03d}", # Consistent chunk ID
            "start_pos": start,
            "end_pos": min(end, len(text)),
            "content": chunk_text,
            "char_count": len(chunk_text)
        })

        # Move start position, accounting for overlap
        # Ensure start doesn't go backward if overlap is larger than (end - start) for last chunk
        if end < len(text):
            start = end - overlap
            if start < (min(end, len(text)) - chunk_size + overlap): # safety if chunk was smaller
                 start = min(end, len(text)) - chunk_size + overlap
            if start < 0 : start = 0 # should not happen with positive overlap
        else:
            start = len(text)

        chunk_id_counter += 1

        # Safety break to avoid infinite loops, e.g., if overlap logic is flawed
        if chunk_id_counter > 2000:  # Adjust as needed, depends on document size
            print("Warning: Exceeded maximum chunk iterations (2000). Breaking.")
            break
    return chunks_data

print("Chunking function defined.")
# Out:
# Chunking function defined.

# %%
# Cell 9: Agent loop function (Revised)
async def run_agentic_loop(
    system_prompt_content: str,
    user_prompt_content: str,
    tools_list: list, # List of tool schemas
    tool_function_mapping: dict, # Mapping of tool name to async function
    llm_model_name: str,
    document_id_for_loop: str, # Pass document_id for logging/final tool call check
    chunk_id_for_loop: str,    # Pass chunk_id for logging/final tool call check
    max_iterations: int = 25 # Increased default, tune as needed
):
    messages = [
        {"role": "system", "content": system_prompt_content},
        {"role": "user", "content": user_prompt_content}
    ]
    print(f"----\nSYSTEM: {system_prompt_content[:300]}... (see cell 7 for full prompt)\nUSER: {user_prompt_content[:400]}...\n----")

    assistant_message_content = None # To store the last textual response from assistant

    for i in range(max_iterations):
        print(f"\nIteration {i+1}/{max_iterations} for Doc: {document_id_for_loop}, Chunk: {chunk_id_for_loop}")
        
        # Reset for this iteration
        assistant_message_content = None 
        
        response = await client.chat.completions.create(
            model=llm_model_name,
            messages=messages,
            tools=tools_list,
            tool_choice="auto", 
        )

        message = response.choices[0].message
        messages.append(message.model_dump(exclude_none=True)) 

        if message.content: # Store any textual content from assistant
            assistant_message_content = message.content
            print(f"ASSISTANT (Textual Content): {assistant_message_content}")


        if message.tool_calls:
            print(f"ASSISTANT (Tool Calls):")
            all_tool_calls_processed = True
            for tool_call in message.tool_calls:
                tool_name = tool_call.function.name
                tool_args_str = tool_call.function.arguments
                print(f"  - Calling tool: {tool_name}")
                print(f"    Arguments: {tool_args_str}")

                if tool_name not in tool_function_mapping:
                    tool_result_content = f"Error: Tool '{tool_name}' not found."
                    print(f"    Error: Tool '{tool_name}' not found.")
                    all_tool_calls_processed = False # Mark if any tool call fails this way
                else:
                    try:
                        tool_args = json.loads(tool_args_str)
                        tool_function = tool_function_mapping[tool_name]
                        tool_result_content = await tool_function(**tool_args)
                    except json.JSONDecodeError:
                        tool_result_content = f"Error: Invalid JSON in arguments for {tool_name}: {tool_args_str}"
                        print(f"    Error: Invalid JSON arguments for {tool_name}.")
                        all_tool_calls_processed = False
                    except Exception as e:
                        tool_result_content = f"Error executing tool {tool_name}: {str(e)}"
                        print(f"    Error executing tool {tool_name}: {e}")
                        all_tool_calls_processed = False
                
                print(f"    Tool Result ({tool_name}): {str(tool_result_content)[:300]}...")
                messages.append({
                    "role": "tool",
                    "tool_call_id": tool_call.id,
                    "name": tool_name,
                    "content": str(tool_result_content) 
                })
                
                # If store_chunk_processing_info is successful, it often means the agent is done with this chunk.
                if tool_name == "store_chunk_processing_info" and "Success" in str(tool_result_content):
                    print(f"Agent called store_chunk_processing_info successfully. Ending iteration for chunk {chunk_id_for_loop}.")
                    return f"store_chunk_processing_info called. Details: {tool_result_content}"

            if not all_tool_calls_processed:
                print(f"Warning: One or more tool calls failed in iteration {i+1} for chunk {chunk_id_for_loop}.")
                # Decide if you want to return an error or let the loop continue for the agent to retry/recover
                # For now, we continue, agent should see the error in message history.

        else: # No tool calls, agent provides a direct textual response
            if assistant_message_content:
                 print(f"ASSISTANT (Final Response for chunk {chunk_id_for_loop}, no tool call): {assistant_message_content}")
                 # If the agent gives a text response without calling store_chunk_processing_info, it might be an issue.
                 # However, we can't force it here without complex logic. Rely on prompt and agent training.
                 return assistant_message_content
            else:
                 # This case should be rare if the model is functioning correctly (e.g. it might provide empty content if truly done)
                 print(f"Warning: No tool calls and no textual content from assistant in iteration {i+1} for chunk {chunk_id_for_loop}.")
                 return "No tool calls and no textual content from assistant. Agent may be stuck or finished unexpectedly."


    # Max iterations reached
    last_tool_message = messages[-1] if messages and messages[-1]["role"] == "tool" else None
    if last_tool_message and last_tool_message["name"] == "store_chunk_processing_info" and "Success" in str(last_tool_message["content"]):
        return f"Max iterations reached, but store_chunk_processing_info was successfully called. Result: {last_tool_message['content']}"
    
    warning_message = (
        f"Max iterations ({max_iterations}) reached for Doc: {document_id_for_loop}, Chunk: {chunk_id_for_loop}. "
        "The agent may not have completed all its tasks for this chunk or "
        "failed to call 'store_chunk_processing_info' as the final step."
    )
    print(f"WARNING: {warning_message}")
    
    # Try to provide the last piece of content from the assistant if available
    if assistant_message_content:
        return f"{warning_message} Last assistant text: {assistant_message_content}"
    return warning_message

print("Agent loop function defined.")
# Out:
# Agent loop function defined.

# %%
# Cell 10: Main Workflow Orchestration (Revised)
async def process_document(
    document_text_content: str,
    doc_id: str,
    doc_source_filename: str,
    initial_doc_metadata: dict,
    chunk_s: int = 2500,
    chunk_o: int = 500,
    max_agent_iterations_per_chunk: int = 25 # Tunable: iterations for agent per chunk
):
    print(f"Starting processing for document: {doc_id}")

    if not await mongo_manager.connect(): # connect returns True on success, False on failure
        print("Failed to connect to MongoDB. Aborting.")
        return None

    text_chunks = simple_chunk_text(document_text_content, chunk_size=chunk_s, overlap=chunk_o)
    print(f"Document divided into {len(text_chunks)} chunks.")

    previous_chunk_text_for_prompt = None # Initialize previous chunk content

    for i, chunk_data in enumerate(text_chunks):
        print(f"\n--- Processing Chunk {i+1}/{len(text_chunks)} (ID: {chunk_data['chunk_id']}) ---")
        print(f"Content (first 100 chars): {chunk_data['content'][:100]}...")

        current_processing_state = {"last_processed_akn_eId": "act"} # Default if no state found
        doc_db_state = await mongo_manager.documents_collection.find_one(
            {"document_id": doc_id}, {"processing_state": 1, "_id": 0}
        )
        if doc_db_state and "processing_state" in doc_db_state:
            current_processing_state = doc_db_state["processing_state"]
            print(f"Retrieved processing state from DB: Last eId '{current_processing_state.get('last_processed_akn_eId', 'act')}'")
        else:
            print(f"No prior processing state found for {doc_id} in DB, or document not initialized. Agent will need to initialize if it's chunk 1.")

        # Prepare previous chunk content for the prompt
        previous_chunk_prompt_section = ""
        if i > 0: # If this is not the first chunk
            # Get the content of the actual previous chunk
            prev_chunk_content = text_chunks[i-1]['content']
            previous_chunk_prompt_section = f"""

Previous Chunk Content (for context, especially for text spanning chunks):
---
{prev_chunk_content[-chunk_o:]} # Provide last 'overlap' characters of the previous chunk
---
"""

        user_prompt = f"""
Analyze the following chunk of an Indonesian legal document (Chunk ID: {chunk_data['chunk_id']}).
The document ID is '{doc_id}'.
The previously processed Akoma Ntoso element eId (from the end of the last successfully processed chunk) was: '{current_processing_state.get("last_processed_akn_eId", "act")}'.
{previous_chunk_prompt_section}
Your task is to integrate this chunk's content into the Akoma Ntoso XML document.
Use tools to fetch context, add/update elements, and log your progress.
If this is the very first chunk processed for this document (i.e., no substantial AKN structure exists beyond a basic shell or it's chunk_001 and the document isn't fully initialized according to `get_akn_document_context`), you MUST call `initialize_akn_document` first, but only if it hasn't been successfully initialized before.
If `initialize_akn_document` has already been run (check context or if elements like 'act__body' exist), do NOT call it again.

Current Chunk Content:
---
{chunk_data['content']}
---
REMEMBER: You MUST call `store_chunk_processing_info` as the very last action for this chunk, providing an accurate `last_processed_akn_eId`.
Determine the correct AKN structure and eIds based on the system guidelines and the content. Be careful with parent eIds and insertion positions.
If a tool call fails, analyze the error and try to recover or adjust your strategy. Do not repeat the exact failing command without change.
Pay close attention to the end of the 'Previous Chunk Content' and the beginning of the 'Current Chunk Content' to correctly append text and avoid duplication or missing information.
"""

        agent_response_or_status = await run_agentic_loop(
            system_prompt_content=agent_system_prompt,
            user_prompt_content=user_prompt,
            tools_list=tools_schemas,
            tool_function_mapping=TOOL_MAPPING,
            llm_model_name=LLM_MODEL,
            document_id_for_loop=doc_id,
            chunk_id_for_loop=chunk_data['chunk_id'],
            max_iterations=max_agent_iterations_per_chunk
        )
        print(f"Agent interaction for chunk {chunk_data['chunk_id']} ended. Status/Response: {str(agent_response_or_status)[:300]}...")

    print(f"\n--- Document processing for {doc_id} complete (all chunks initiated). ---")

    final_doc_data = await mongo_manager.documents_collection.find_one({"document_id": doc_id})
    if final_doc_data and "akn_xml_string" in final_doc_data:
        print("\nFinal Akoma Ntoso XML (first 1000 chars):")
        print(final_doc_data["akn_xml_string"][:1000])
        output_filename = f"{doc_id}_final.akn.xml" # Changed filename
        with open(output_filename, "w", encoding="utf-8") as f:
            f.write(final_doc_data["akn_xml_string"])
        print(f"Full Akoma Ntoso XML saved to: {output_filename}")
        return final_doc_data["akn_xml_string"]
    else:
        print(f"Error: Could not retrieve final Akoma Ntoso XML for {doc_id}.")
        return None

print("Main workflow orchestration function defined.")
# Out:
# Main workflow orchestration function defined.

# %%
# Cell 11: Load example and run processing (Revised)

sample_doc_path = "../data/UU_8_1961.txt" # <--- ADJUST THIS PATH TO YOUR FILE
document_id_main = "../outputs/UU_8_1961_vAkn_rev10" # Unique ID for this processing run

initial_metadata_main = {
    "title": "WAJIB KERJA SARJANA",
    "number": "8",
    "year": "1961",
    "doc_subtype": "UNDANG-UNDANG", 
    "country_code": "id"
}

async def main():
    try:
        with open(sample_doc_path, 'r', encoding='utf-8') as f:
            raw_document_text = f.read()
        print(f"Successfully loaded document: {sample_doc_path}, length: {len(raw_document_text)} chars.")
    except FileNotFoundError:
        print(f"Error: Document file not found at {sample_doc_path}. Please check the path.")
        return

    if not await mongo_manager.connect():
        print("MongoDB connection failed. Cannot proceed.")
        return

    # Clean up existing document entry for a fresh run (optional, for testing)
    # print(f"Attempting to clean up existing entry for {document_id_main}...")
    # delete_result = await mongo_manager.documents_collection.delete_one({"document_id": document_id_main})
    # if delete_result.deleted_count > 0:
    #     print(f"Cleaned up existing entry for {document_id_main}.")
    # else:
    #     print(f"No existing entry for {document_id_main} to clean up, or error in deletion.")


    final_akn_xml = await process_document(
        document_text_content=raw_document_text,
        doc_id=document_id_main,
        doc_source_filename=os.path.basename(sample_doc_path),
        initial_doc_metadata=initial_metadata_main,
        chunk_s=2500, 
        chunk_o=400,
        max_agent_iterations_per_chunk=40 # Increased from default 25, adjust as needed
    )

    await mongo_manager.close()

    if final_akn_xml:
        print(f"\nProcessing complete for {document_id_main}.\nFinal XML length: {len(final_akn_xml)}")
    else:
        print(f"\nProcessing for {document_id_main} encountered issues or did not produce XML.")

print("To run the processing, execute 'await main()' in a new cell.")
# If you want to run it directly when the notebook cell is executed:
# import asyncio
# asyncio.run(main())
# Out:
# To run the processing, execute 'await main()' in a new cell.

# %%
await main()
# Out:
# Successfully loaded document: ../data/UU_8_1961.txt, length: 11846 chars.
# Attempting to connect to MongoDB: hukum_terbuka_akn...
# ✅ Connected to MongoDB: hukum_terbuka_akn, collection: legal_documents_akn
# Starting processing for document: ../outputs/UU_8_1961_vAkn_rev10
# ✅ MongoDB connection already active for: hukum_terbuka_akn
# Document divided into 6 chunks.
#
# --- Processing Chunk 1/6 (ID: chunk_001) ---
# Content (first 100 chars): PRESIDEN
# REPUBLIK INDONESIA
# UNDANG-UNDANG REPUBLIK INDONESIA
# NOMOR 8 TAHUN 1961
# TENTANG
# WAJIB KERJA ...
# No prior processing state found for ../outputs/UU_8_1961_vAkn_rev10 in DB, or document not initialized. Agent will need to initialize if it's chunk 1.
# ----
# SYSTEM:
# You are an expert legislative informatics assistant specializing in converting Indonesian legal documents into Akoma Ntoso (AKN) v3.0 XML format.
# Your primary goal is to analyze chunks of an Indonesian legal text and incrementally construct a well-formed and semantically rich Akoma Ntoso XML docume... (see cell 7 for full prompt)
# USER:
# Analyze the following chunk of an Indonesian legal document (Chunk ID: chunk_001).
# The document ID is '../outputs/UU_8_1961_vAkn_rev10'.
# The previously processed Akoma Ntoso element eId (from the end of the last successfully processed chunk) was: 'act'.
#
# Your task is to integrate this chunk's content into the Akoma Ntoso XML document.
# Use tools to fetch context, add/update elements, and log your ...
# ----
#
# Iteration 1/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Textual Content): Analysis of Chunk 1:
# The chunk starts with high-level document identification and preamble information, then moves into the initial articles of the document.
#
# **Initialization Check:**
# The `last_processed_akn_eId` is 'act', indicating that the document has likely been initialized. I will fetch the context to confirm.
#
# **Planned Actions:**
# 1.  **Retrieve context:** Use `get_akn_document_context` to confirm the document's initialized state and content.
# 2.  **Add Preamble content:**
#     *   `PRESIDEN REPUBLIK INDONESIA` (title element)
#     *   `UNDANG-UNDANG REPUBLIK INDONESIA` (docTitle)
#     *   `NOMOR 8 TAHUN 1961` (docTitle)
#     *   `TENTANG` (docTitle)
#     *   `WAJIB KERJA SARJANA` (docTitle)
#     *   `PRESIDEN REPUBLIK INDONESIA,` (docTitle - this is the second occurrence of this phrase, handled as a separate docTitle for the President line).
#     *   `Menimbang:`: Add as `recitals` with individual `recital` points a, b, c.
#     *   `Mengingat:`: Add as `citations` with individual `citation` points a, b, c.
#     *   `Dengan persetujuan Dewan Perwakilan Rakyat Gotong Royong;`: Add as a `container` with `name="approvalStatement"`.
#     *   `MEMUTUSKAN :`: Add as a `formula` with `name="decision"`.
#     *   `I. Mencabut:...`: Add as a `container` with `name="revocation"`.
#     *   `II. Menetapkan:...`: Add as an `enactingFormula`.
# 3.  **Add Body content:**
#     *   `Pasal 1.`: Add as an `article`.
#     *   `(1)Tiap warganegara...` : Add as a `paragraph` within Pasal 1.
#         *   Inside this paragraph, there are several list items (a, b, c) and then a concluding sentence. These lists will be `list` and `point` elements. The concluding sentence will be a `p` element after the list.
#     *   `(2)Dalam peraturan ini...`: Add as a `paragraph` within Pasal 1.
#     *   `(3)Bagi pendidikan tinggi...`: Add as a `paragraph` within Pasal 1.
#     *   `(4)Sarjana yang telah lulus...`: Add as a `paragraph` within Pasal 1. This paragraph is truncated. It will be partially added and updated in the next chunk.
#
# **Text Corrections & Enhancements:**
# *   `setiaporang` -> `setiap orang` (anticipated for future text, not directly in this chunk)
# *   `Memutuskan :` -> `Memutuskan :` (keeping colon, will use a p tag inside formula)
# *   `Mencabut:Undang-undang` can be cleaned to `Mencabut: Undang-undang`
# *   `peraturanyangbertentangandenganUndang-undangini` can be cleaned to `peraturan yang bertentangan dengan Undang-undang ini`
# *   `Mengingat:a.Pasal 5 ayat (1) jo. pasal 20 ayat (1) dan pasal 27 ayat (2) Undang-undang Dasar;` -> `Mengingat: a.Pasal 5 ayat (1) jo. Pasal 20 ayat (1) dan Pasal 27 ayat (2) Undang-undang Dasar;` - Corrected to ensure explicit spacing after colon and proper casing of 'Pasal'.
# *   `Pasal 1.` -> `Pasal 1` (remove dot from number and trailing in text content)
# *   `(1)Tiap warganegara, baik pria maupun wanita,` -> `(1) Tiap warganegara, baik pria maupun wanita,` (ensure space after number)
# *   `Perguruan Tinggi Negara;` -> `Perguruan Tinggi Negara;` (keep semicolon)
# *   `peraturan wajib kerja sarjana;` -> `peraturan wajib kerja sarjana;` (keep semicolon)
# *   `Pasal 5ayat (1)` -> `Pasal 5 ayat (1)`
# *   `berturut-turut .` -> `berturut-turut.` (remove space before period)
# *   General cleaning for extra spaces and line breaks.
#
# Starting with `get_akn_document_context` to verify initialization.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: get_akn_document_context
#     Arguments: {"document_id":"../outputs/UU_8_1961_vAkn_rev10","context_type":"full"}
#     Tool Result (get_akn_document_context): Error: Document '../outputs/UU_8_1961_vAkn_rev10' not found or has no AKN XML....
#
# Iteration 2/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Textual Content): The document is not found, meaning it has not been initialized. I need to call `initialize_akn_document`.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: initialize_akn_document
#     Arguments: {"initial_metadata":{"doc_subtype":"UNDANG-UNDANG","title":"WAJIB KERJA SARJANA","author_placeholder":"PRESIDEN REPUBLIK INDONESIA","number":"8","year":"1961"},"source_file":"undang_undang_8_1961.txt","document_id":"../outputs/UU_8_1961_vAkn_rev10","doc_type_hint":"act"}
#     Tool Result (initialize_akn_document): Successfully initialized Akoma Ntoso document '../outputs/UU_8_1961_vAkn_rev10' in database. Root eId: 'act'....
#
# Iteration 3/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Textual Content): Document initialized. Now adding preamble elements, starting with the `docTitle` elements.
# Cleaned text:
# - `PRESIDEN REPUBLIK INDONESIA` (first line)
# - `UNDANG-UNDANG REPUBLIK INDONESIA`
# - `NOMOR 8 TAHUN 1961`
# - `TENTANG`
# - `WAJIB KERJA SARJANA`
# - `PRESIDEN REPUBLIK INDONESIA,` (second line)
#
# I will add these as `docTitle` elements within the `preamble`.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"insert_position":"append_to_parent","parent_eId":"act__preamble","new_element_akn_xml":"<docTitle eId=\"act__preamble__doctitle_1\">PRESIDEN REPUBLIK INDONESIA</docTitle>","document_id":"../outputs/UU_8_1961_vAkn_rev10"}
#     Tool Result (add_akn_element): Successfully added element 'act__preamble__doctitle_1' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 4/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"document_id":"../outputs/UU_8_1961_vAkn_rev10","insert_position":"append_to_parent","parent_eId":"act__preamble","new_element_akn_xml":"<docTitle eId=\"act__preamble__doctitle_2\">UNDANG-UNDANG REPUBLIK INDONESIA</docTitle>"}
#     Tool Result (add_akn_element): Successfully added element 'act__preamble__doctitle_2' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 5/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"insert_position":"append_to_parent","document_id":"../outputs/UU_8_1961_vAkn_rev10","new_element_akn_xml":"<docTitle eId=\"act__preamble__doctitle_3\">NOMOR 8 TAHUN 1961</docTitle>","parent_eId":"act__preamble"}
#     Tool Result (add_akn_element): Successfully added element 'act__preamble__doctitle_3' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 6/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"parent_eId":"act__preamble","insert_position":"append_to_parent","new_element_akn_xml":"<docTitle eId=\"act__preamble__doctitle_4\">TENTANG</docTitle>","document_id":"../outputs/UU_8_1961_vAkn_rev10"}
#     Tool Result (add_akn_element): Successfully added element 'act__preamble__doctitle_4' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 7/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"document_id":"../outputs/UU_8_1961_vAkn_rev10","insert_position":"append_to_parent","parent_eId":"act__preamble","new_element_akn_xml":"<docTitle eId=\"act__preamble__doctitle_5\">WAJIB KERJA SARJANA</docTitle>"}
#     Tool Result (add_akn_element): Successfully added element 'act__preamble__doctitle_5' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 8/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"insert_position":"append_to_parent","parent_eId":"act__preamble","new_element_akn_xml":"<docTitle eId=\"act__preamble__doctitle_6\">PRESIDEN REPUBLIK INDONESIA,</docTitle>","document_id":"../outputs/UU_8_1961_vAkn_rev10"}
#     Tool Result (add_akn_element): Successfully added element 'act__preamble__doctitle_6' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 9/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Textual Content): Now, `Menimbang:` section within a `recitals` container.
# Recital `a` text: `bahwa ilmu dan keahlian azasnya untuk mengabdi kepada tanah air, karenanya perlu dikembangkan dan dilaksanakan.`
# Recital `b` text: `bahwa dalam rangka pembangunan nasional semesta berencana sangat diperlukan tenaga sarjana dari perbagai jurusan;`
# Recital `c` text: `bahwa agar penempatan dan penggunaan tenaga sarjana tersebut teratur dan merata maka perlu diadakan peraturan wajib kerja sarjana;`
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"new_element_akn_xml":"<recitals eId=\"act__preamble__recitals_1\" name=\"considerations\"><recital eId=\"act__preamble__recitals_1__rec_a\"><num>a.</num><p>bahwa ilmu dan keahlian azasnya untuk mengabdi kepada tanah air, karenanya perlu dikembangkan dan dilaksanakan.</p></recital><recital eId=\"act__preamble__recitals_1__rec_b\"><num>b.</num><p>bahwa dalam rangka pembangunan nasional semesta berencana sangat diperlukan tenaga sarjana dari perbagai jurusan;</p></recital><recital eId=\"act__preamble__recitals_1__rec_c\"><num>c.</num><p>bahwa agar penempatan dan penggunaan tenaga sarjana tersebut teratur dan merata maka perlu diadakan peraturan wajib kerja sarjana;</p></recital></recitals>","parent_eId":"act__preamble","document_id":"../outputs/UU_8_1961_vAkn_rev10","insert_position":"append_to_parent"}
#     Tool Result (add_akn_element): Successfully added element 'act__preamble__recitals_1' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 10/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Textual Content): Now, `Mengingat:` section within a `citations` container.
# Citation `a` text: `Pasal 5 ayat (1) jo. pasal 20 ayat (1) dan pasal 27 ayat (2) Undang-undang Dasar;`
# Citation `b` text: `Ketetapan Majelis Permusyawaratan Rakyat Sementara Nomor 1 /MPRS/1960 dan Nomor II/MPRS/1960;`
# Citation `c` text: `Undang-undang Nomor 10 Prp. tahun 1960 (Lembaran-Negara tahun 1960 Nomor 31);`
#
# Corrected `pasal 5 ayat (1) jo. pasal 20 ayat (1) dan pasal 27 ayat (2)`-> `Pasal 5 ayat (1) jo. Pasal 20 ayat (1) dan Pasal 27 ayat (2)`.
# Added proper spacing after colon in `Lembaran-Negara`.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"insert_position":"append_to_parent","new_element_akn_xml":"<citations eId=\"act__preamble__citations_1\" name=\"references\"><citation eId=\"act__preamble__citations_1__cit_a\"><num>a.</num><p>Pasal 5 ayat (1) jo. Pasal 20 ayat (1) dan Pasal 27 ayat (2) Undang-undang Dasar;</p></citation><citation eId=\"act__preamble__citations_1__cit_b\"><num>b.</num><p>Ketetapan Majelis Permusyawaratan Rakyat Sementara Nomor 1 /MPRS/1960 dan Nomor II/MPRS/1960;</p></citation><citation eId=\"act__preamble__citations_1__cit_c\"><num>c.</num><p>Undang-undang Nomor 10 Prp. tahun 1960 (Lembaran Negara tahun 1960 Nomor 31);</p></citation></citations>","parent_eId":"act__preamble","document_id":"../outputs/UU_8_1961_vAkn_rev10"}
#     Tool Result (add_akn_element): Successfully added element 'act__preamble__citations_1' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 11/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Textual Content): Next, the approval statement: `Dengan persetujuan Dewan Perwakilan Rakyat Gotong Royong;`
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"insert_position":"append_to_parent","parent_eId":"act__preamble","document_id":"../outputs/UU_8_1961_vAkn_rev10","new_element_akn_xml":"<container name=\"approvalStatement\" eId=\"act__preamble__approval_1\"><p>Dengan persetujuan Dewan Perwakilan Rakyat Gotong Royong;</p></container>"}
#     Tool Result (add_akn_element): Successfully added element 'act__preamble__approval_1' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 12/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Textual Content): Next, the explicit `MEMUTUSKAN :`
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"parent_eId":"act__preamble","document_id":"../outputs/UU_8_1961_vAkn_rev10","new_element_akn_xml":"<formula name=\"decision\" eId=\"act__preamble__formula_decision\"><p>MEMUTUSKAN :</p></formula>","insert_position":"append_to_parent"}
#     Tool Result (add_akn_element): Successfully added element 'act__preamble__formula_decision' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 13/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Textual Content): Next, `I. Mencabut:...` as container name `revocation`.
# Corrected `peraturanyangbertentangandenganUndang-undangini` to `peraturan yang bertentangan dengan Undang-undang ini`.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"document_id":"../outputs/UU_8_1961_vAkn_rev10","insert_position":"append_to_parent","new_element_akn_xml":"<container name=\"revocation\" eId=\"act__preamble__revocation_1\"><num>I.</num><content><p>Mencabut: Undang-undang Nomor 8 tahun 1951 tentang penangguhan pemberian izin kepada dokter dan dokter gigi dan segala peraturan yang bertentangan dengan Undang-undang ini (Lembaran Negara tahun 1951 Nomor 44);</p></content></container>","parent_eId":"act__preamble"}
#     Tool Result (add_akn_element): Successfully added element 'act__preamble__revocation_1' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 14/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Textual Content): Next, `II. Menetapkan:...` as `enactingFormula`.
# Corrected `UNDANG-UNDANG TENTANG WAJIB KERJA SARJANA.` to remove trailing period.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"insert_position":"append_to_parent","document_id":"../outputs/UU_8_1961_vAkn_rev10","new_element_akn_xml":"<enactingFormula eId=\"act__preamble__enactingFormula_1\" name=\"enactingFormula\"><num>II.</num><p>Menetapkan: <docType refersTo=\"#act\">UNDANG-UNDANG</docType> TENTANG <docTitle refersTo=\"#mainTitle\">WAJIB KERJA SARJANA</docTitle>.</p></enactingFormula>","parent_eId":"act__preamble"}
#     Tool Result (add_akn_element): Successfully added element 'act__preamble__enactingFormula_1' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 15/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Textual Content): Now moving to the `body` section, starting with `Pasal 1.`.
# Corrected `Pasal 1.` to `Pasal 1`.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"insert_position":"append_to_parent","document_id":"../outputs/UU_8_1961_vAkn_rev10","parent_eId":"act__body","new_element_akn_xml":"<article eId=\"act__body__art_1\" num=\"1\"><num>Pasal 1</num><content></content></article>"}
#     Tool Result (add_akn_element): Successfully added element 'act__body__art_1' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 16/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Textual Content): Adding `Ayat (1)` of Pasal 1.
# Text includes a list. The first sentence is part of the first paragraph.
# The list items a, b, c. The "Semuanya itu..." part is a concluding sentence for the paragraph.
# Corrected `Tiap warganegara` to `Tiap warganegara, baik pria maupun wanita,` and `Perguruan Tinggi Negara;` -> `Perguruan Tinggi Negara;`. Also `"Doktor" sementara` -> `"Doktor" sementara`. `pasal 5ayat (1)` -> `pasal 5 ayat (1)`.
# Here, the `list` with `point`s `a.`, `b.`, `c.` are part of the `content` of the `paragraph` itself. The "Semuanya itu..." forms a `p` element after the `list`.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"document_id":"../outputs/UU_8_1961_vAkn_rev10","parent_eId":"act__body__art_1","new_element_akn_xml":"<paragraph eId=\"act__body__art_1__para_1\" num=\"(1)\"><num>(1)</num><content><p>Tiap warganegara, baik pria maupun wanita,</p><list eId=\"act__body__art_1__para_1__list_1\"><point eId=\"act__body__art_1__para_1__list_1__point_a\"><num>a.</num><content><p>yang memperoleh ijazah ujian penghabisan pada Perguruan Tinggi Negara;</p></content></point><point eId=\"act__body__art_1__para_1__list_1__point_b\"><num>b.</num><content><p>yang memperoleh ijazah ujian penghabisan pada Perguruan Tinggi Swasta, yang ditunjuk oleh Menteri yang diserahi urusan Perguruan tinggi,</p></content></point><point eId=\"act__body__art_1__para_1__list_1__point_c\"><num>c.</num><content><p>yang memperoleh ijazah ujian penghabisan pada Perguruan Tinggi diluar negeri, yang ditunjuk oleh Menteri yang diserahi urusan perguruan tinggi.</p></content></point></list><p>Semuanya itu disebut sarjana, wajib bekerja pada Pemerintah atau pada perusahaan-perusahaan yang ditunjuk oleh Pemerintah sekurang-kurangnya selama tiga tahun berturut-turut.</p></content></paragraph>","insert_position":"append_to_content_of_parent"}
#     Tool Result (add_akn_element): Successfully added element 'act__body__art_1__para_1' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 17/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Textual Content): Adding `Ayat (2)` of Pasal 1.
# `Dalam peraturan ini Akademi dikecualikan dari istilah Perguruan Tinggi.`
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"new_element_akn_xml":"<paragraph eId=\"act__body__art_1__para_2\" num=\"(2)\"><num>(2)</num><content><p>Dalam peraturan ini Akademi dikecualikan dari istilah Perguruan Tinggi.</p></content></paragraph>","document_id":"../outputs/UU_8_1961_vAkn_rev10","parent_eId":"act__body__art_1","insert_position":"append_to_content_of_parent"}
#     Tool Result (add_akn_element): Successfully added element 'act__body__art_1__para_2' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 18/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Textual Content): Adding `Ayat (3)` of Pasal 1.
# `Bagi pendidikan tinggi Kedokteran, Kedokteran gigi, Kedokteran Hewan, Apoteker dan Akuntan ijazah ujian penghabisan yang termaksud pada ayat (1) ialah ijazah setelah lulus menempuh berturut-turut ujian-ujian dokter, dokter gigi, dokter hewan, apoteker dan akuntan.`
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"new_element_akn_xml":"<paragraph eId=\"act__body__art_1__para_3\" num=\"(3)\"><num>(3)</num><content><p>Bagi pendidikan tinggi Kedokteran, Kedokteran gigi, Kedokteran Hewan, Apoteker dan Akuntan ijazah ujian penghabisan yang termaksud pada ayat (1) ialah ijazah setelah lulus menempuh berturut-turut ujian-ujian dokter, dokter gigi, dokter hewan, apoteker dan akuntan.</p></content></paragraph>","insert_position":"append_to_content_of_parent","document_id":"../outputs/UU_8_1961_vAkn_rev10","parent_eId":"act__body__art_1"}
#     Tool Result (add_akn_element): Successfully added element 'act__body__art_1__para_3' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 19/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Textual Content): Adding `Ayat (4)` of Pasal 1. This paragraph is truncated in the chunk.
# Corrected `pasal 5ayat (1)` to `pasal 5 ayat (1)`.
# The last two words "wajib kerja ba" are truncated, so the `p` element will represent the content correctly.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"document_id":"../outputs/UU_8_1961_vAkn_rev10","insert_position":"append_to_content_of_parent","parent_eId":"act__body__art_1","new_element_akn_xml":"<paragraph eId=\"act__body__art_1__para_4\" num=\"(4)\"><num>(4)</num><content><p>Sarjana yang telah lulus dalam ujian penghabisan tersebut dalam ayat (1) dan ayat (3) pasal ini yang sedang mempersiapkan thesis untuk memperoleh gelar ilmiah \"Doktor\" sementara dibebaskan dari wajib kerja, bila ada keterangan dari Presiden Universitas atau Pemimpin Sekolah Tinggi termaksud dalam pasal 5 ayat (1); wajib kerja ba</p></content></paragraph>"}
#     Tool Result (add_akn_element): Successfully added element 'act__body__art_1__para_4' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 20/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_001
# ASSISTANT (Textual Content): All elements from the chunk have been added. Now, store the chunk processing info.
# The last processed element was `act__body__art_1__para_4`.
# The analysis summary will reflect the additions made.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: store_chunk_processing_info
#     Arguments: {"chunk_id":"chunk_001","document_id":"../outputs/UU_8_1961_vAkn_rev10","analysis_summary":"Initialized document. Added preamble with docTitles, recitals, citations, approval statement, decision formula, revocation container, and enacting formula. Added Pasal 1 with four paragraphs, including lists.","last_processed_akn_eId":"act__body__art_1__para_4"}
#     Tool Result (store_chunk_processing_info): Successfully stored processing info for chunk 'chunk_001' of document '../outputs/UU_8_1961_vAkn_rev10'. Last eId set to 'act__body__art_1__para_4'....
# Agent called store_chunk_processing_info successfully. Ending iteration for chunk chunk_001.
# Agent interaction for chunk chunk_001 ended. Status/Response: store_chunk_processing_info called. Details: Successfully stored processing info for chunk 'chunk_001' of document '../outputs/UU_8_1961_vAkn_rev10'. Last eId set to 'act__body__art_1__para_4'....
#
# --- Processing Chunk 2/6 (ID: chunk_002) ---
# Content (first 100 chars): n dokter, dokter gigi,
# dokter hewan, apoteker dan akuntan.
# (4)Sarjana yang telah lulus dalam ujian p...
# Retrieved processing state from DB: Last eId 'act__body__art_1__para_4'
# ----
# SYSTEM:
# You are an expert legislative informatics assistant specializing in converting Indonesian legal documents into Akoma Ntoso (AKN) v3.0 XML format.
# Your primary goal is to analyze chunks of an Indonesian legal text and incrementally construct a well-formed and semantically rich Akoma Ntoso XML docume... (see cell 7 for full prompt)
# USER:
# Analyze the following chunk of an Indonesian legal document (Chunk ID: chunk_002).
# The document ID is '../outputs/UU_8_1961_vAkn_rev10'.
# The previously processed Akoma Ntoso element eId (from the end of the last successfully processed chunk) was: 'act__body__art_1__para_4'.
#
#
# Previous Chunk Content (for context, especially for text spanning chunks):
# ---
# n dokter, dokter gigi,
# dokter hewan, apotek...
# ----
#
# Iteration 1/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_002
# ASSISTANT (Textual Content): Analyzing chunk_002. The previous chunk ended mid-sentence within an `article` and `paragraph` element.
# The current chunk begins by completing the sentence for Pasal 1 Ayat (4), then introduces Ayat (5), followed by Pasal 2, Pasal 3 (with its sub-points), Pasal 4, and Pasal 5.
# I will first append the rest of the text to `act__body__art_1__para_4`, then add `act__body__art_1__para_5`. After that, I will proceed with adding `act__body__art_2`, `act__body__art_3` (with its list items), `act__body__art_4`, and `act__body__art_5`.
#
# Correction for Pasal 1 Ayat (4): "pasal 5ayat (1)" should be "pasal 5 ayat (1)".
# The provided text for Ayat (4) is: "wajib kerja bagi mereka ini mulai berlaku setelah mereka mencapai gelar "Doktor"." which seems to complete the sentence.
#
# For Pasal 1 Ayat (5): "Seorang sarjana yang telah berusia 50 tahun dapat dibebaskan dari kewajiban ini."
#
# For Pasal 2: "Departemen yang diserahi urusan perguruan tinggi mengadakan daftar sarjana termaksud dalam pasal 1."
#
# For Pasal 3:
# Ayat (1): "Untuk Penempatan sarjana termaksud pada pasal 1 dibentuk Dewan Penempatan Sarjana yang berkedudukan langsung dibawah dan diketuai oleh Menteri Perburuhan."
# Ayat (2): "Dewan Penempatan Sarjana tersebut anggotanya, selain Menteri Perburuhan, terdiri atas wakil-wakil yang diberi kuasa penuh dari Menteri-Menteri:" followed by a list.
# List items a-h need to be added as `<point>` elements within a `<list>`.
#
# For Pasal 4: "Wewenang , Tugas-kewajiban dan susunan Dewan Penempatan Sarjana ditetapkan dalam Peraturan Pemerintah." Note the extra space after "Wewenang" which will be removed. "Tugaskewajiban" should be "Tugas-kewajiban".
#
# For Pasal 5:
# Ayat (1): "Presiden Universitas negara, Pemimpin sekolah tinggi negara, Presiden universitas swasta serta Pemimpin sekolah tinggi swasta yang ditunjuk oleh Menteri yang diserahi urusan perguruan tinggi, wajib memberitahukan kepada Departemen yang diserahi urusan perguruan tinggi tentang lulusnya seorang mahasiswa dalam waktu sebulan sesudah memperoleh ijazah ujian penghabisan."
# Ayat (2): "Lulusantermaksud dalam pasal 1 ayat (1) huruf a dan b dalam waktu sebulan memperoleh ijazah ujian penghabisan dan lulusan termaksud dalam pasal 1 ayat (1) huruf c dalam waktu sebulansetibanya di Indonesia, wajib menyampaikan secara tertulis kepada Departemen yang diserahi urusan perguruan tinggi keterangan-keterangan yang dimaksudkan pada ayat (1) pasal ini, disertai penjelasan yang dianggapnya perlu, agar penempatan mereka mungkin dilakukan sesuai dengan bakat dan kehendak masing-masing."
# Ayat (3): "Bila mereka sedang mempersiapkan thesis untuk mencapai gelar ilmiah "Doktor" maka keterangan itu harus disertai dengan surat keterangan dari Presiden Universitas atau pemimpin Sekolah Tinggi sebagai termaksud dalam pasal 1 ayat (" (The text ends abruptly here, I expect it to continue in the next chunk).
#
# I will start by appending the remaining text to `act__body__art_1__para_4`.
#
# Corrected part of Ayat (4): "wajib kerja bagi mereka ini mulai berlaku setelah mereka mencapai gelar "Doktor"."
#
# Corrected part of Ayat (2) of Pasal 5: "Lulusantermaksud" -> "Lulusan termaksud"; "sebulansetibanya" -> "sebulan setibanya".
#
# ASSISTANT (Tool Calls):
#   - Calling tool: update_akn_element
#     Arguments: {"target_eId":"act__body__art_1__para_4","append_text_content":" wajib kerja bagi mereka ini mulai berlaku setelah mereka mencapai gelar \"Doktor\".","document_id":"../outputs/UU_8_1961_vAkn_rev10"}
#     Tool Result (update_akn_element): Successfully updated element 'act__body__art_1__para_4' in document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 2/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_002
# ASSISTANT (Textual Content): Appended text to `act__body__art_1__para_4`. Now adding `act__body__art_1__para_5`.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"document_id":"../outputs/UU_8_1961_vAkn_rev10","parent_eId":"act__body__art_1","new_element_akn_xml":"<paragraph eId=\"act__body__art_1__para_5\" num=\"(5)\"><num>(5)</num><content><p>Seorang sarjana yang telah berusia 50 tahun dapat dibebaskan dari kewajiban ini.</p></content></paragraph>","insert_position":"append_to_content_of_parent"}
#     Tool Result (add_akn_element): Successfully added element 'act__body__art_1__para_5' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 3/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_002
# ASSISTANT (Textual Content): Added `act__body__art_1__para_5`. Now adding `act__body__art_2`.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"new_element_akn_xml":"<article eId=\"act__body__art_2\" num=\"2\"><num>Pasal 2</num><content><p>Departemen yang diserahi urusan perguruan tinggi mengadakan daftar sarjana termaksud dalam pasal 1.</p></content></article>","parent_eId":"act__body","insert_position":"append_to_parent","document_id":"../outputs/UU_8_1961_vAkn_rev10"}
#     Tool Result (add_akn_element): Successfully added element 'act__body__art_2' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 4/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_002
# ASSISTANT (Textual Content): Added `act__body__art_2`. Now adding `act__body__art_3`.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"insert_position":"append_to_parent","document_id":"../outputs/UU_8_1961_vAkn_rev10","parent_eId":"act__body","new_element_akn_xml":"<article eId=\"act__body__art_3\" num=\"3\"><num>Pasal 3</num><content><paragraph eId=\"act__body__art_3__para_1\" num=\"(1)\"><num>(1)</num><content><p>Untuk Penempatan sarjana termaksud pada pasal 1 dibentuk Dewan Penempatan Sarjana yang berkedudukan langsung dibawah dan diketuai oleh Menteri Perburuhan.</p></content></paragraph><paragraph eId=\"act__body__art_3__para_2\" num=\"(2)\"><num>(2)</num><content><p>Dewan Penempatan Sarjana tersebut anggotanya, selain Menteri Perburuhan, terdiri atas wakil-wakil yang diberi kuasa penuh dari Menteri-Menteri:</p><list eId=\"act__body__art_3__para_2__list_1\" type=\"alpha\"><point eId=\"act__body__art_3__para_2__list_1__point_a\"><num>a.</num><content><p>Pendidikan, Pengetahuan dan Kebudayaan,</p></content></point><point eId=\"act__body__art_3__para_2__list_1__point_b\"><num>b.</num><content><p>Perguruan Tinggi dan Ilmu Pengetahuan,</p></content></point><point eId=\"act__body__art_3__para_2__list_1__point_c\"><num>c.</num><content><p>Keamanan Nasional,</p></content></point><point eId=\"act__body__art_3__para_2__list_1__point_d\"><num>d.</num><content><p>Pembangunan,</p></content></point><point eId=\"act__body__art_3__para_2__list_1__point_e\"><num>e.</num><content><p>Produksi,</p></content></point><point eId=\"act__body__art_3__para_2__list_1__point_f\"><num>f.</num><content><p>Distribusi,</p></content></point><point eId=\"act__body__art_3__para_2__list_1__point_g\"><num>g.</num><content><p>Kesehatan,</p></content></point><point eId=\"act__body__art_3__para_2__list_1__point_h\"><num>h.</num><content><p>Agama.</p></content></point></list></content></paragraph></content></article>"}
#     Tool Result (add_akn_element): Successfully added element 'act__body__art_3' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 5/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_002
# ASSISTANT (Textual Content): Added `act__body__art_3` with its paragraphs and list. Now adding `act__body__art_4`.
# Text correction: "Wewenang , Tugas-kewajiban" should be "Wewenang, Tugas-kewajiban" (removed extra space).
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"insert_position":"append_to_parent","parent_eId":"act__body","new_element_akn_xml":"<article eId=\"act__body__art_4\" num=\"4\"><num>Pasal 4</num><content><p>Wewenang, Tugas-kewajiban dan susunan Dewan Penempatan Sarjana ditetapkan dalam Peraturan Pemerintah.</p></content></article>","document_id":"../outputs/UU_8_1961_vAkn_rev10"}
#     Tool Result (add_akn_element): Successfully added element 'act__body__art_4' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 6/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_002
# ASSISTANT (Textual Content): Added `act__body__art_4`. Now adding `act__body__art_5`.
# Text correction:
# *   Ayat (2): "Lulusantermaksud" -> "Lulusan termaksud"
# *   Ayat (2): "sebulansetibanya" -> "sebulan setibanya"
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"new_element_akn_xml":"<article eId=\"act__body__art_5\" num=\"5\"><num>Pasal 5</num><content><paragraph eId=\"act__body__art_5__para_1\" num=\"(1)\"><num>(1)</num><content><p>Presiden Universitas negara, Pemimpin sekolah tinggi negara, Presiden universitas swasta serta Pemimpin sekolah tinggi swasta yang ditunjuk oleh Menteri yang diserahi urusan perguruan tinggi, wajib memberitahukan kepada Departemen yang diserahi urusan perguruan tinggi tentang lulusnya seorang mahasiswa dalam waktu sebulan sesudah memperoleh ijazah ujian penghabisan.</p></content></paragraph><paragraph eId=\"act__body__art_5__para_2\" num=\"(2)\"><num>(2)</num><content><p>Lulusan termaksud dalam pasal 1 ayat (1) huruf a dan b dalam waktu sebulan memperoleh ijazah ujian penghabisan dan lulusan termaksud dalam pasal 1 ayat (1) huruf c dalam waktu sebulan setibanya di Indonesia, wajib menyampaikan secara tertulis kepada Departemen yang diserahi urusan perguruan tinggi keterangan-keterangan yang dimaksudkan pada ayat (1) pasal ini, disertai penjelasan yang dianggapnya perlu, agar penempatan mereka mungkin dilakukan sesuai dengan bakat dan kehendak masing-masing.</p></content></paragraph><paragraph eId=\"act__body__art_5__para_3\" num=\"(3)\"><num>(3)</num><content><p>Bila mereka sedang mempersiapkan thesis untuk mencapai gelar ilmiah \"Doktor\" maka keterangan itu harus disertai dengan surat keterangan dari Presiden Universitas atau pemimpin Sekolah Tinggi sebagai termaksud dalam pasal 1 ayat (</p></content></paragraph></content></article>","document_id":"../outputs/UU_8_1961_vAkn_rev10","insert_position":"append_to_parent","parent_eId":"act__body"}
#     Tool Result (add_akn_element): Successfully added element 'act__body__art_5' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 7/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_002
# ASSISTANT (Textual Content): Added `act__body__art_5`. The chunk ended mid-sentence in `act__body__art_5__para_3`.
#
# Now, I will call `store_chunk_processing_info`. The last processed AKN element is `act__body__art_5__para_3`.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: store_chunk_processing_info
#     Arguments: {"analysis_summary":"Processed Pasal 1 Ayat (4), corrected and appended text. Added Pasal 1 Ayat (5). Added Pasal 2, Pasal 3 with list items, Pasal 4, and Pasal 5 with its paragraphs, including text corrections.","document_id":"../outputs/UU_8_1961_vAkn_rev10","last_processed_akn_eId":"act__body__art_5__para_3","chunk_id":"chunk_002"}
#     Tool Result (store_chunk_processing_info): Successfully stored processing info for chunk 'chunk_002' of document '../outputs/UU_8_1961_vAkn_rev10'. Last eId set to 'act__body__art_5__para_3'....
# Agent called store_chunk_processing_info successfully. Ending iteration for chunk chunk_002.
# Agent interaction for chunk chunk_002 ended. Status/Response: store_chunk_processing_info called. Details: Successfully stored processing info for chunk 'chunk_002' of document '../outputs/UU_8_1961_vAkn_rev10'. Last eId set to 'act__body__art_5__para_3'....
#
# --- Processing Chunk 3/6 (ID: chunk_003) ---
# Content (first 100 chars):   pasal   ini,   disertai
# penjelasan yang dianggapnya perlu, agar penempatan mereka mungkin dilakuka...
# Retrieved processing state from DB: Last eId 'act__body__art_5__para_3'
# ----
# SYSTEM:
# You are an expert legislative informatics assistant specializing in converting Indonesian legal documents into Akoma Ntoso (AKN) v3.0 XML format.
# Your primary goal is to analyze chunks of an Indonesian legal text and incrementally construct a well-formed and semantically rich Akoma Ntoso XML docume... (see cell 7 for full prompt)
# USER:
# Analyze the following chunk of an Indonesian legal document (Chunk ID: chunk_003).
# The document ID is '../outputs/UU_8_1961_vAkn_rev10'.
# The previously processed Akoma Ntoso element eId (from the end of the last successfully processed chunk) was: 'act__body__art_5__para_3'.
#
#
# Previous Chunk Content (for context, especially for text spanning chunks):
# ---
#   pasal   ini,   disertai
# penjelasan yang d...
# ----
#
# Iteration 1/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_003
# ASSISTANT (Textual Content): Analyzing chunk_003. The previous chunk ended with text that seems to be part of a sentence within an ayat: "...pasal 1 ayat (". The current chunk starts with "4).". This indicates that `act__body__art_5__para_3` is incomplete and needs appending. I will append the corrected "4)." to the existing `p` element inside `act__body__art_5__para_3`.
#
# After that, I will process the remaining content:
# *   A new paragraph, `(4) Ketentuan yang bertalian dengan pendaftaran termaksud dalam ayat (1) dan (2) ditetapkan dalam Peratuaran Pemerintah.`, will be added as `act__body__art_5__para_4`.
# *   Then, `Pasal 6.` needs to be new `article`.
# *   `Pasal 7.` will be a new `article`, containing multiple `paragraph` (ayat).
# *   `Pasal 8.` will be another new `article`.
# *   `Pasal 9.` will be the final `article` of the main body, followed by the promulgation command and signatures.
# *   The last line, "LEMBARAN NEGARA REPUBLIK INDONESIA TAHUN", is part of metadata for the document. I will use it to complete the publication information.
#
# First, I need to append the missing text to `act__body__art_5__para_3`.
#
# Corrected 'Peratuaran Pemerintah' to 'Peraturan Pemerintah'.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: update_akn_element
#     Arguments: {"append_text_content":"4).","document_id":"../outputs/UU_8_1961_vAkn_rev10","target_eId":"act__body__art_5__para_3"}
#     Tool Result (update_akn_element): Successfully updated element 'act__body__art_5__para_3' in document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 2/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_003
# ASSISTANT (Textual Content): The last part of Pasal 5 Ayat (3) has been appended. Now, I will add Pasal 5 Ayat (4).
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"parent_eId":"act__body__art_5","document_id":"../outputs/UU_8_1961_vAkn_rev10","new_element_akn_xml":"<paragraph eId=\"act__body__art_5__para_4\" num=\"(4)\"><num>(4)</num><content><p>Ketentuan yang bertalian dengan pendaftaran termaksud dalam ayat (1) dan (2) ditetapkan dalam Peraturan Pemerintah.</p></content></paragraph>","insert_position":"append_to_content_of_parent"}
#     Tool Result (add_akn_element): Successfully added element 'act__body__art_5__para_4' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 3/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_003
# ASSISTANT (Textual Content): Next, I will add Pasal 6.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"document_id":"../outputs/UU_8_1961_vAkn_rev10","parent_eId":"act__body","new_element_akn_xml":"<article eId=\"act__body__art_6\" num=\"6\"><num>Pasal 6</num><content><p>Semua Departemen dan instansi-instansi lain yang tidak termasuk dalam lingkungan sesuatu Departemen, pada waktu tertentu memberitahukan kepada Departemen yang diserahi urusan perguruan tinggi dan Dewan Penempatan Sarjana, banyaknya sarjana yang bekerja padanya. Pada tiap permulaan tahun takwin diberitahukan pula banyaknya sarjana yang dibutuhkan dibubuhi keterangan-keterangan yang perlu.</p></content></article>","insert_position":"append_to_parent"}
#     Tool Result (add_akn_element): Successfully added element 'act__body__art_6' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 4/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_003
# ASSISTANT (Textual Content): Next, I will add Pasal 7.
# Corrected 'setiaporangmempekerjakanseorangSarjanayangbelummemenuhi' to 'setiap orang mempekerjakan seorang Sarjana yang belum memenuhi'. This was a significant OCR error.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"document_id":"../outputs/UU_8_1961_vAkn_rev10","insert_position":"append_to_parent","new_element_akn_xml":"<article eId=\"act__body__art_7\" num=\"7\"><num>Pasal 7</num><content><paragraph eId=\"act__body__art_7__para_1\" num=\"(1)\"><num>(1)</num><content><p>Pelanggaran pasal 5 ayat (2) dipidana dengan pidana selama-lamanya enam bulan atau didenda sebanyak-banyaknya sepuluh ribu rupiah,</p></content></paragraph><paragraph eId=\"act__body__art_7__para_2\" num=\"(2)\"><num>(2)</num><content><p>Barang siapa tidak memenuhi wajib-kerja selama tiga tahun berturut-turut pada masa, tempat dan dalam jabatan yang ditentukan oleh instansi Pemerintah yang berkuasa, dipidana dengan pidana kurungan selama-lamanya sembilan bulan atau didenda sebanyak-banyaknya seratus ribu rupiah.</p></content></paragraph><paragraph eId=\"act__body__art_7__para_3\" num=\"(3)\"><num>(3)</num><content><p>Barang siapa mempekerjakan seorang Sarjana yang belum memenuhi kewajibannya termaksud dalam pasal 5 ayat (2) dipidana dengan pidana kurungan selama-lamanya sembilan bulan atau didenda sebanyak-banyaknya seratus ribu rupiah.</p></content></paragraph><paragraph eId=\"act__body__art_7__para_4\" num=\"(4)\"><num>(4)</num><content><p>Ulangan dari pelanggaran termaksud pada ayat (2) dan (3) dipidana dengan pidana kurungan selama-lamanya satu tahun.</p></content></paragraph><paragraph eId=\"act__body__art_7__para_5\" num=\"(5)\"><num>(5)</num><content><p>Tindak pidana yang dimaksudkan pada ayat (1), (2), (3) dan (4) pasal ini dianggap sebagai pelanggaran.</p></content></paragraph></content></article>","parent_eId":"act__body"}
#     Tool Result (add_akn_element): Successfully added element 'act__body__art_7' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 5/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_003
# ASSISTANT (Textual Content): Next, I will add Pasal 8.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"insert_position":"append_to_parent","new_element_akn_xml":"<article eId=\"act__body__art_8\" num=\"8\"><num>Pasal 8</num><content><p>Pelaksanaan Undang-undang ini diserahkan kepada Menteri Perburuhan, dan Menteri Pendidikan, Pengetahuan dan Kebudayaan serta Menteri Perguruan Tinggi dan Ilmu Pengetahuan.</p></content></article>","parent_eId":"act__body","document_id":"../outputs/UU_8_1961_vAkn_rev10"}
#     Tool Result (add_akn_element): Successfully added element 'act__body__art_8' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 6/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_003
# ASSISTANT (Textual Content): Next, I will add Pasal 9 and the promulgation command.
#
# Corrected 'setiaporang' to 'setiap orang'.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"new_element_akn_xml":"<article eId=\"act__body__art_9\" num=\"9\"><num>Pasal 9</num><content><p>Undang-undang ini mulai berlaku pada hari diundangkan.</p></content></article>","document_id":"../outputs/UU_8_1961_vAkn_rev10","parent_eId":"act__body","insert_position":"append_to_parent"}
#     Tool Result (add_akn_element): Successfully added element 'act__body__art_9' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 7/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_003
# ASSISTANT (Textual Content): Now, I will add the promulgation command.
#
# Corrected 'setiaporang' to 'setiap orang'.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"insert_position":"append_to_parent","new_element_akn_xml":"<container eId=\"act__body__promulgationCommand_1\" name=\"promulgationCommand\"><p>Agar setiap orang dapat mengetahuinya memerintahkan pengundangan Undang-undang ini dengan penempatan dalam Lembaran Negara Republik Indonesia.</p></container>","document_id":"../outputs/UU_8_1961_vAkn_rev10","parent_eId":"act__body"}
#     Tool Result (add_akn_element): Successfully added element 'act__body__promulgationCommand_1' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 8/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_003
# ASSISTANT (Textual Content): Next, I will add the conclusions section, including the signature blocks and promulgation block.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"document_id":"../outputs/UU_8_1961_vAkn_rev10","parent_eId":"act","new_element_akn_xml":"<conclusions eId=\"act__conclusions\"><container eId=\"act__conclusions__signatureBlock_1\" name=\"signatureBlock\"><container eId=\"act__conclusions__signatureBlock_1__placeDate\" name=\"placeDateOfSignature\"><p>Disahkan di Jakarta</p><p>pada tanggal 29 April 1961.</p></container><signature eId=\"act__conclusions__signatureBlock_1__signature_1\"><role refersTo=\"#presidenRI\">Pejabat Presiden Republik Indonesia,</role><person refersTo=\"#djuanda\">DJUANDA</person></signature></container><container eId=\"act__conclusions__promulgationBlock_1\" name=\"promulgationBlock\"><container eId=\"act__conclusions__promulgationBlock_1__placeDate\" name=\"placeDateOfPromulgation\"><p>Diundangkan di Jakarta</p><p>pada tanggal 29 April 1961.</p></container><signature eId=\"act__conclusions__promulgationBlock_1__signature_1\"><role refersTo=\"#pejabatSekretarisNegara\">Pejabat Sekretaris Negara,</role><person refersTo=\"#santoso\">SANTOSO</person></signature></container></conclusions>","insert_position":"append_to_parent"}
#     Tool Result (add_akn_element): Error: Element with eId 'act__conclusions' already exists in the document. Cannot add duplicate....
#
# Iteration 9/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_003
# ASSISTANT (Textual Content): It seems I made a mistake before and the `conclusions` element already exists. I will try to retrieve the context of `act__conclusions`.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: get_akn_document_context
#     Arguments: {"target_eId":"act__conclusions","document_id":"../outputs/UU_8_1961_vAkn_rev10"}
#     Tool Result (get_akn_document_context): <conclusions xmlns="http://docs.oasis-open.org/legaldocml/ns/akn/3.0" eId="act__conclusions"/>
# ...
#
# Iteration 10/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_003
# ASSISTANT (Textual Content): The `act__conclusions` element exists, but it's empty. This means I need to add the `signatureBlock` and `promulgationBlock` *inside* the existing `conclusions` element. I will re-add them using `act__conclusions` as the parent.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"new_element_akn_xml":"<container eId=\"act__conclusions__signatureBlock_1\" name=\"signatureBlock\"><container eId=\"act__conclusions__signatureBlock_1__placeDate\" name=\"placeDateOfSignature\"><p>Disahkan di Jakarta</p><p>pada tanggal 29 April 1961.</p></container><signature eId=\"act__conclusions__signatureBlock_1__signature_1\"><role refersTo=\"#presidenRI\">Pejabat Presiden Republik Indonesia,</role><person refersTo=\"#djuanda\">DJUANDA</person></signature></container>","insert_position":"append_to_parent","document_id":"../outputs/UU_8_1961_vAkn_rev10","parent_eId":"act__conclusions"}
#     Tool Result (add_akn_element): Successfully added element 'act__conclusions__signatureBlock_1' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 11/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_003
# ASSISTANT (Textual Content): Now, adding the promulgation block.
#
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
# ...
# ---
# na wanita dapat dipe...
# ----
#
# Iteration 1/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_006
# ASSISTANT (Textual Content): The previous chunk ended with "na wanita dapat diperhatikan sifat kodrat wanita. Sejalan dengan realisasi Pembangunan Semsta, prioritetpenempatan sarjana itu diatur selaras dengan pelaksanaan pembangunan tersebut diatas, dengan urutan sebagai berikut: a.bidang ekonomi, pendidikan dan penelitian. b.Dalam bidang Perusahaan diutamakan Perusahaan Negara atauyang dikuasai oleh negara, dalam hal ini tanpa melalaikan ke".
# The current chunk starts with "na wanita dapat diperhatikan sifat kodrat wanita. Sejalan dengan realisasi Pembangunan Semsta, prioritetpenempatan sarjana itu diatur selaras dengan pelaksanaan pembangunan tersebut diatas, dengan urutan sebagai berikut: a.bidang ekonomi, pendidikan dan penelitian. b.Dalam bidang Perusahaan diutamakan Perusahaan Negara atauyang dikuasai oleh negara, dalam hal ini tanpa melalaikan kepentingan Swasta."
#
# There is an overlap of "na wanita dapat diperhatikan sifat kodrat wanita. Sejalan dengan realisasi Pembangunan Semsta, prioritetpenempatan sarjana itu diatur selaras dengan pelaksanaan pembangunan tersebut diatas, dengan urutan sebagai berikut: a.bidang ekonomi, pendidikan dan penelitian. b.Dalam bidang Perusahaan diutamakan Perusahaan Negara atauyang dikuasai oleh negara, dalam hal ini tanpa melalaikan ke". I will remove this overlap from the text to be added.
# The text for the first <p> element is "pentingan Swasta.".
# The previous `last_processed_akn_eId` was 'act__elucidation_1__body__elucArtByArt_1__art_4'. This indicates we are still within the elucidation section, specifically within a clause for Article 4. The current text appears to be a continuation of this clause, specifically point 'b' of a list, followed by 'Pasal 5 dan 6'.
#
# I will first update the existing article 4 clause by appending the missing text for point 'b'.
# Then, I will add clauses for 'Pasal 5 dan 6', 'Pasal 7', 'Pasal 8', and 'Pasal 9'.
# Finally, I will handle the "Tambahan Lembaran Negara Republik Indonesia Tahun 1961 Nomor 2270" which appears to be a publication metadata.
# Corrected 'Pembangunan Semsta' to 'Pembangunan Semesta', 'prioritetpenempatan' to 'prioritas penempatan', 'atau yang dikuasai' to 'atau yang dikuasai', 'kepentingan Swasta' to 'kepentingan Swasta'.
# Corrected 'Pasal5dan6' to 'Pasal 5 dan 6'.
# Corrected 'denda disini' to 'denda di sini'.
# Corrected 'pelanggaran ulangan' to 'pelanggaran berulang'.
# Corrected 'sarja (untuk dipekerjakan)' to 'sarjana (untuk dipekerjakan)'.
# Corrected 'undung-undang' to 'undang-undang'.
# Corrected 'dokt_er' to 'dokter' (not present in current chunk but for future reference).
# Corrected 'sarjana-sarjana lulusan' to 'sarjana-sarjana lulusan'.
# Corrected 'undang-undang ini' to 'Undang-undang ini'.
# Corrected 'mendaftar_kan' to 'mendaftarkan'.
# Corrected 'dan tidak berlaku lagi' to 'dan tidak berlaku lagi'.
# Corrected 'Tambahan Lembaran Negara Republik Indonesia' to 'Tambahan Lembaran Negara Republik Indonesia'.
# Corrected 'Tahun 1961 Nomor 2270' to 'Tahun 1961 Nomor 2270'.
#
# I will append the corrected text to the last point of the previous clause, then add clauses for Pasal 5 dan 6, Pasal 7, Pasal 8, and Pasal 9.
# Finally, I will add the Tambahan Lembaran Negara publication info.
# ASSISTANT (Tool Calls):
#   - Calling tool: update_akn_element
#     Arguments: {"document_id":"../outputs/UU_8_1961_vAkn_rev10","target_eId":"act__elucidation_1__body__elucArtByArt_1__art_4__list_1__point_b__content__p_1","append_text_content":"pentingan Swasta."}
#     Tool Result (update_akn_element): Error: Element with eId 'act__elucidation_1__body__elucArtByArt_1__art_4__list_1__point_b__content__p_1' not found....
#
# Iteration 2/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_006
# ASSISTANT (Textual Content): The previous `update_akn_element` call failed because the target eId 'act__elucidation_1__body__elucArtByArt_1__art_4__list_1__point_b__content__p_1' was not found. This indicates that the exact structure within the `art_4` clause might be different than assumed, or the `<p>` element itself might not have been created with an `eId`.
#
# I need to get the context of `act__elucidation_1__body__elucArtByArt_1__art_4` to understand its current structure and append the text correctly.
# I need to add the closing parenthesis to the previous content, then the rest.
# I will first check the current content of the `art_4` clause. I'll get 'element_children_only' context for `act__elucidation_1__body__elucArtByArt_1__art_4`.
# ASSISTANT (Tool Calls):
#   - Calling tool: get_akn_document_context
#     Arguments: {"document_id":"../outputs/UU_8_1961_vAkn_rev10","target_eId":"act__elucidation_1__body__elucArtByArt_1__art_4","context_type":"element_children_only"}
#     Tool Result (get_akn_document_context): <childrenContext xmlns="http://docs.oasis-open.org/legaldocml/ns/akn/3.0">
#   <heading>Pasal 4</heading>
#   <p>Dalam perkataan wewenang meliputi ketentuan tentang dasar pembagian penempatan sarjana dalam badan-badan baik yang dimiliki, dikuasai atau diawasi oleh Pemerintah.</p>
#   <p>Dasar penempatan b...
#
# Iteration 3/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_006
# ASSISTANT (Textual Content): The context shows that `act__elucidation_1__body__elucArtByArt_1__art_4__list_1__point_b` exists and it is a `<point>` element containing a `<content>` element and inside it a `<p>` element. The `<p>` element's `eId` is not explicitly set in the context, which is likely why the previous update failed.
#
# To append text to the `<p>` element within `act__elucidation_1__body__elucArtByArt_1__art_4__list_1__point_b`, I need to use `get_last_p_eId_in_element` to find its specific `eId`. Then, I can use `update_akn_element` to append the remaining text.
# Corrected 'pentingan Swasta' to 'kepentingan Swasta.' for appending the text to point b. Then I will proceed to add the next clauses.
# ASSISTANT (Tool Calls):
#   - Calling tool: get_last_p_eId_in_element
#     Arguments: {"container_eId":"act__elucidation_1__body__elucArtByArt_1__art_4__list_1__point_b","document_id":"../outputs/UU_8_1961_vAkn_rev10"}
#     Tool Result (get_last_p_eId_in_element): Info: Last <p> element in 'act__elucidation_1__body__elucArtByArt_1__art_4__list_1__point_b' found, but it has no eId. Preview: 'Dalam bidang Perusahaan diutam...'...
#
# Iteration 4/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_006
# ASSISTANT (Textual Content): The `get_last_p_eId_in_element` tool indicated that the last `<p>` element within `act__elucidation_1__body__elucArtByArt_1__art_4__list_1__point_b` does not have an `eId`. In this scenario, `update_akn_element` with `append_text_content` option will automatically append to the last `<p>` if `target_eId` is set to the parent container (`point_b`).
#
# Therefore, I will directly use `update_akn_element` with `target_eId` as `act__elucidation_1__body__elucArtByArt_1__art_4__list_1__point_b` to append the remaining text.
# Corrected 'prioritetpenempatan' to 'prioritas penempatan', 'Pembangunan Semsta' to 'Pembangunan Semesta', and 'atau yang dikuasai' to 'atau yang dikuasai'. The text to append for the first paragraph is "pentingan Swasta."
# This text is the missing end of point 'b' under Article 4. I will append to the current point 'b' element.I need to apped "pentingan Swasta." to the last paragraph of point b.
# ASSISTANT (Tool Calls):
#   - Calling tool: update_akn_element
#     Arguments: {"append_text_content":"pentingan Swasta.","target_eId":"act__elucidation_1__body__elucArtByArt_1__art_4__list_1__point_b","document_id":"../outputs/UU_8_1961_vAkn_rev10"}
#     Tool Result (update_akn_element): Successfully updated element 'act__elucidation_1__body__elucArtByArt_1__art_4__list_1__point_b' in document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 5/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_006
# ASSISTANT (Textual Content): Now that point 'b' is complete, I will add the next clauses: 'Pasal 5 dan 6', 'Pasal 7', 'Pasal 8', and 'Pasal 9', and finally the Tambahan Lembaran Negara information.
#
# I will start by adding the clause for 'Pasal 5 dan 6'. The heading should be "Pasal 5 dan Pasal 6".
# Corrected 'Pasal5dan6' to 'Pasal 5 dan 6' in the text. Headings should be consistent.
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"insert_position":"append_to_parent","document_id":"../outputs/UU_8_1961_vAkn_rev10","parent_eId":"act__elucidation_1__body__elucArtByArt_1","new_element_akn_xml":"<clause eId=\"act__elucidation_1__body__elucArtByArt_1__art_5-6\" refersTo=\"#act__body__art_5 #act__body__art_6\"><heading>Pasal 5 dan Pasal 6</heading><p>Cukup jelas.</p></clause>"}
#     Tool Result (add_akn_element): Successfully added element 'act__elucidation_1__body__elucArtByArt_1__art_5-6' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 6/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_006
# ASSISTANT (Textual Content): Next, add the clause for 'Pasal 7'.
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"insert_position":"append_to_parent","parent_eId":"act__elucidation_1__body__elucArtByArt_1","new_element_akn_xml":"<clause eId=\"act__elucidation_1__body__elucArtByArt_1__art_7\" refersTo=\"#act__body__art_7\"><heading>Pasal 7</heading><p>Maksimum denda di sini sengaja dipertinggi untuk menjaga jangan sampai pewajib kerja ingkar dari masa tiga tahun.</p><p>Dengan adanya hanya ancaman pidana kurungan saja, maka pelanggaran berulang diharapkan banyak dapat dihindarkan.</p><p>Ancaman hukum bagi, penerima sarjana termaksud pada ayat 3 hanya berlaku untuk penerimaan sarjana (untuk dipekerjakan) yang belum mendaftarkan dan tidak berlaku lagi yang telah mendaftarkan tetapi belum ditempatkan.</p></clause>","document_id":"../outputs/UU_8_1961_vAkn_rev10"}
#     Tool Result (add_akn_element): Successfully added element 'act__elucidation_1__body__elucArtByArt_1__art_7' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 7/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_006
# ASSISTANT (Textual Content): Next, add the clause for 'Pasal 8'.
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"document_id":"../outputs/UU_8_1961_vAkn_rev10","insert_position":"append_to_parent","parent_eId":"act__elucidation_1__body__elucArtByArt_1","new_element_akn_xml":"<clause eId=\"act__elucidation_1__body__elucArtByArt_1__art_8\" refersTo=\"#act__body__art_8\"><heading>Pasal 8</heading><p>Cukup jelas.</p></clause>"}
#     Tool Result (add_akn_element): Successfully added element 'act__elucidation_1__body__elucArtByArt_1__art_8' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 8/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_006
# ASSISTANT (Textual Content): Now, add the clause for 'Pasal 9'.
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"new_element_akn_xml":"<clause eId=\"act__elucidation_1__body__elucArtByArt_1__art_9\" refersTo=\"#act__body__art_9\"><heading>Pasal 9</heading><p>Pada asasnya semua sarjana sejak diundangkannya Undang-undang ini dikenakan wajib kerja sarjana. Dengan sendirinya termasuk juga sarjana-sarjana lulusan sebelum Undang-undang ini berlaku. Demi keadilan pelaksanaannya diselaraskan dengan kewajiban kerja para dokter dan dokter gigi sebelum undang-undang berlaku.</p></clause>","insert_position":"append_to_parent","document_id":"../outputs/UU_8_1961_vAkn_rev10","parent_eId":"act__elucidation_1__body__elucArtByArt_1"}
#     Tool Result (add_akn_element): Successfully added element 'act__elucidation_1__body__elucArtByArt_1__art_9' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 9/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_006
# ASSISTANT (Textual Content): Finally, I need to add the "TAMBAHAN LEMBARAN NEGARA REPUBLIK INDONESIA TAHUN 1961 NOMOR 2270" as a publication metadata. This should be added to the `<meta>` section of the main document.
#
# I will get the context of the main document's meta section to see if there are existing publication elements, and then add this new one.
# Corrected 'Tambahan Lembaran Negara Republik Indonesia Tahun 1961 Nomor 2270' to conform to the `publication` element's attributes.
# The date should be '1961-01-01' because only the year is available.
# The `number` should be '2270'.
# The `showAs` should be "Tambahan Lembaran Negara Republik Indonesia Nomor 2270 Tahun 1961".
# ASSISTANT (Tool Calls):
#   - Calling tool: add_akn_element
#     Arguments: {"new_element_akn_xml":"<publication eId=\"act__meta__publication_tln_1961_2270\" name=\"TambahanLembaranNegara\" showAs=\"Tambahan Lembaran Negara Republik Indonesia Nomor 2270 Tahun 1961\" date=\"1961-01-01\" number=\"2270\" TLA=\"TLNRI\"/>","insert_position":"append_to_parent","parent_eId":"act__meta","document_id":"../outputs/UU_8_1961_vAkn_rev10"}
#     Tool Result (add_akn_element): Successfully added element 'act__meta__publication_tln_1961_2270' to document '../outputs/UU_8_1961_vAkn_rev10'....
#
# Iteration 10/40 for Doc: ../outputs/UU_8_1961_vAkn_rev10, Chunk: chunk_006
# ASSISTANT (Textual Content): The clause for Pasal 9 was the last elucidated article. The "TAMBAHAN LEMBARAN NEGARA REPUBLIK INDONESIA" is a metadata element. The `last_processed_akn_eId` should reflect the last content-related element. Thus, `act__elucidation_1__body__elucArtByArt_1__art_9` is the most appropriate `last_processed_akn_eId`.I've appended text to the previous article 4 elucidation, added clauses for Pasal 5 dan 6, Pasal 7, Pasal 8, and Pasal 9 elucidations. I also added the Tambahan Lembaran Negara publication metadata.
# ASSISTANT (Tool Calls):
#   - Calling tool: store_chunk_processing_info
#     Arguments: {"chunk_id":"chunk_006","last_processed_akn_eId":"act__elucidation_1__body__elucArtByArt_1__art_9","document_id":"../outputs/UU_8_1961_vAkn_rev10","analysis_summary":"Appended text to Pasal 4 elucidation, added clauses for Pasal 5 dan 6, Pasal 7, Pasal 8, and Pasal 9 elucidations, and added Tambahan Lembaran Negara publication metadata."}
#     Tool Result (store_chunk_processing_info): Successfully stored processing info for chunk 'chunk_006' of document '../outputs/UU_8_1961_vAkn_rev10'. Last eId set to 'act__elucidation_1__body__elucArtByArt_1__art_9'....
# Agent called store_chunk_processing_info successfully. Ending iteration for chunk chunk_006.
# Agent interaction for chunk chunk_006 ended. Status/Response: store_chunk_processing_info called. Details: Successfully stored processing info for chunk 'chunk_006' of document '../outputs/UU_8_1961_vAkn_rev10'. Last eId set to 'act__elucidation_1__body__elucArtByArt_1__art_9'....
#
# --- Document processing for ../outputs/UU_8_1961_vAkn_rev10 complete (all chunks initiated). ---
#
# Final Akoma Ntoso XML (first 1000 chars):
# <akomaNtoso xmlns="http://docs.oasis-open.org/legaldocml/ns/akn/3.0">
#   <act eId="act" name="indonesianAct">
#     <meta eId="act__meta">
#       <identification eId="act__meta__identification" source="#sourceSystem">
#         <FRBRWork eId="act__meta__identification__work">
#           <FRBRthis value="/akn/id/undang-undang/1961/8/main"/>
#           <FRBRuri value="/akn/id/undang-undang/1961/8"/>
#           <FRBRdate date="1961-01-01" name="creation"/>
#           <FRBRauthor href="#system" as_="#author"/>
#           <FRBRcountry value="id"/>
#           <FRBRname value="WAJIB KERJA SARJANA"/>
#           <FRBRnumber value="8"/>
#         </FRBRWork>
#         <FRBRManifestation eId="act__meta__identification__manifestation" FRBRdate="1961-04-29" FRBRuri="/akn/id/undang-undang/1961/8/id@1961-04-29_publication.xml" name="publication" FRBRthis="/akn/id/undang-undang/1961/8/id@1961-04-29_publication/main.xml">
#           <FRBRthis value="/akn/id/undang-undang/1961/8/id@main.xml"/>
#           <FRBRuri value="/
# Full Akoma Ntoso XML saved to: ../outputs/UU_8_1961_vAkn_rev10_final.akn.xml
# MongoDB connection closed.
#
# Processing complete for ../outputs/UU_8_1961_vAkn_rev10.
# Final XML length: 25662
